# %% [markdown]
# ## RETICULOCYTE COUNT TEST USING SSD RESNET 50 CLASS LOSS WEIGHT AUGMENTED

# %% [markdown]
# This is a collaboratory notebook for training SSD ResNet model. It has got the scripts to create confusion matrix and count per classes, also it has custom script to pereform following postprocessing Tests.
#
# 1. Duplicate Object removal
# 2. Partial Object removal

# %% [markdown]
# ### PERFORM GDRIVE MOUNTING AND CLONE THE REPOSITORY

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/TensorFlow'
# Out:
# /content/gdrive/My Drive/TensorFlow

# %% [markdown]
# ### INSTALL AND SETUP OBJECT DETECTION TF MODEL ZOO

# %% [markdown]
# Download the tensorflow models from Git Hub

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 58094, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 58094 (delta 111), reused 248 (delta 96), pack-reused 57831
# Receiving objects: 100% (58094/58094), 572.96 MiB | 14.95 MiB/s, done.
# Resolving deltas: 100% (40234/40234), done.
# Checking out files: 100% (2480/2480), done.

# %%
# !apt-get install protobuf-compiler python-lxml python-pil
# !pip install Cython pandas tf-slim lvis
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 40 not upgraded.
# Need to get 1,614 kB of archives.
# After this operation, 8,908 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-chardet all 3.0.4-1 [80.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-webencodings all 0.5-2 [10.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-html5lib all 0.999999999-1 [83.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-lxml amd64 4.2.1-1ubuntu0.4 [897 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pil amd64 5.1.0-1ubuntu0.6 [302 kB]
# Fetched 1,614 kB in 1s (1,130 kB/s)
# Selecting previously unselected package python-bs4.
# (Reading database ... 160837 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.4_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.4) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.6_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.6) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.4) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.6) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 7.8 MB/s
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf-slim) (0.12.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis) (4.1.2.30)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (0.10.0)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (2.4.7)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from lvis) (3.2.2)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis) (1.3.1)
# Installing collected packages: tf-slim, lvis
# Successfully installed lvis-0.5.3 tf-slim-1.1.0

# %%
# %cd '/content/gdrive/My Drive/TensorFlow/models/research/'
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/gdrive/My Drive/TensorFlow/models/research

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Jul 31 08:47:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import sys
os.environ['PYTHONPATH']+=":/content/gdrive/My Drive/TensorFlow/models"
sys.path.append("/content/gdrive/My Drive/TensorFlow/models/research")

# %%
pwd
# Out:
# '/content/gdrive/My Drive/TensorFlow/models/research'

# %%
# %%bash
# cp object_detection/packages/tf2/setup.py .
# python setup.py build
# python setup.py install
# Out:
# running build
# running build_py
# copying object_detection/protos/anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/argmax_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_predictor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/calibration_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/center_net_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/eval_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/fpn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/flexible_grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/graph_rewriter_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/hyperparams_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/image_resizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/input_reader_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/losses_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/keypoint_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/mean_stddev_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/model_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/optimizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/multiscale_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/pipeline_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/preprocessor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/post_processing_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/region_similarity_calculator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/square_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/string_int_label_map_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/target_assigner_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/train_pb2.py -> build/lib/object_detection/protos
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/__init__.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/CONTRIBUTING.md -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/README.md -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/exporter_lib_v2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_graph_tf2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_graph_lib_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/exporter_lib_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/exporter_main_v2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_ssd_graph_lib_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/exporter_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/eval_util_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/eval_util.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_ssd_graph_lib.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_graph_lib_tf2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_tflite_ssd_graph.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/exporter.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/export_inference_graph.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/inputs.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_tpu_main.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_main_tf2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_lib.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_lib_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_main.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_lib_v2.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/inputs_test.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_hparams.py -> build/bdist.linux-x86_64/egg/object_detection
# copying build/lib/object_detection/model_lib_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection
# creating build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/multiscale_grid_anchor_generator.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/multiple_grid_anchor_generator.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/grid_anchor_generator.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/flexible_grid_anchor_generator_test.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/grid_anchor_generator_test.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/multiple_grid_anchor_generator_test.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/flexible_grid_anchor_generator.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# copying build/lib/object_detection/anchor_generators/multiscale_grid_anchor_generator_test.py -> build/bdist.linux-x86_64/egg/object_detection/anchor_generators
# creating build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/keypoint_box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/mean_stddev_box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/square_box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/square_box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/faster_rcnn_box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/mean_stddev_box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/keypoint_box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/faster_rcnn_box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# creating build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/losses_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_predictor_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/image_resizer_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/calibration_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_coder_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/graph_rewriter_builder_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/anchor_generator_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/hyperparams_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/dataset_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/matcher_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/region_similarity_calculator_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/dataset_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/image_resizer_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/target_assigner_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/decoder_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/region_similarity_calculator_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/anchor_generator_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/target_assigner_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/calibration_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_coder_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/matcher_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/losses_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_predictor_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/input_reader_builder_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/input_reader_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/graph_rewriter_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/post_processing_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/preprocessor_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/decoder_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/post_processing_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/hyperparams_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/preprocessor_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# creating build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/balanced_positive_negative_sampler.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/matcher_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_predictor.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/keypoint_ops.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/target_assigner_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/region_similarity_calculator.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/region_similarity_calculator_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_ops.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/model.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/densepose_ops.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/batch_multiclass_nms_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/anchor_generator.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/batcher_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/prefetcher_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/target_assigner.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/balanced_positive_negative_sampler_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/standard_fields.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_sync_batch_norm.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/class_agnostic_nms_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/batcher.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/data_decoder.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor_cache.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/densepose_ops_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/losses.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_ops_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/matcher.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/minibatch_sampler_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/keypoint_ops_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/multiclass_nms_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/post_processing.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/losses_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/model_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/minibatch_sampler.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/prefetcher.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_batch_norm.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/data_parser.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_batch_norm_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/core
# copying build/lib/object_detection/core/box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/core
# creating build/bdist.linux-x86_64/egg/object_detection/data_decoders
# copying build/lib/object_detection/data_decoders/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/data_decoders
# copying build/lib/object_detection/data_decoders/tf_sequence_example_decoder_test.py -> build/bdist.linux-x86_64/egg/object_detection/data_decoders
# copying build/lib/object_detection/data_decoders/tf_sequence_example_decoder.py -> build/bdist.linux-x86_64/egg/object_detection/data_decoders
# copying build/lib/object_detection/data_decoders/tf_example_decoder_test.py -> build/bdist.linux-x86_64/egg/object_detection/data_decoders
# copying build/lib/object_detection/data_decoders/tf_example_decoder.py -> build/bdist.linux-x86_64/egg/object_detection/data_decoders
# creating build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/oid_hierarchical_labels_expansion.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_kitti_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/tf_record_creation_util.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/download_and_preprocess_mscoco.sh -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_oid_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/oid_tfrecord_creation.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_pascal_tf_record_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_ava_actions_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/seq_example_util.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_coco_tf_record_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_pycocotools_package.sh -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/download_and_preprocess_ava.sh -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/seq_example_util_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/oid_tfrecord_creation_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_coco_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/tf_record_creation_util_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_pet_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_pascal_tf_record.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/oid_hierarchical_labels_expansion_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# copying build/lib/object_detection/dataset_tools/create_kitti_tf_record_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools
# creating build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/add_context_to_examples.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/generate_embedding_data_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/create_cococameratraps_tfexample_main.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/generate_embedding_data.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/generate_detection_data.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/add_context_to_examples_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/generate_detection_data_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# copying build/lib/object_detection/dataset_tools/context_rcnn/create_cococameratraps_tfexample_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/context_rcnn
# creating build/bdist.linux-x86_64/egg/object_detection/dataset_tools/densepose
# copying build/lib/object_detection/dataset_tools/densepose/UV_symmetry_transforms.mat -> build/bdist.linux-x86_64/egg/object_detection/dataset_tools/densepose
# creating build/bdist.linux-x86_64/egg/object_detection/inference
# copying build/lib/object_detection/inference/detection_inference.py -> build/bdist.linux-x86_64/egg/object_detection/inference
# copying build/lib/object_detection/inference/detection_inference_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/inference
# copying build/lib/object_detection/inference/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/inference
# copying build/lib/object_detection/inference/infer_detections.py -> build/bdist.linux-x86_64/egg/object_detection/inference
# creating build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/eval.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/trainer_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/trainer.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/evaluator.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/train.py -> build/bdist.linux-x86_64/egg/object_detection/legacy
# creating build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/bipartite_matcher_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/hungarian_matcher.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/bipartite_matcher.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/argmax_matcher_test.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/hungarian_matcher_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# copying build/lib/object_detection/matchers/argmax_matcher.py -> build/bdist.linux-x86_64/egg/object_detection/matchers
# creating build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/center_net_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/deepmac_meta_arch_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_meta_arch_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/center_net_meta_arch_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch_test_lib.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/deepmac_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/rfcn_meta_arch.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf2.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch_test_lib.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/rfcn_meta_arch_test.py -> build/bdist.linux-x86_64/egg/object_detection/meta_architectures
# creating build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation_utils_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_tools_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_evaluation_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_evaluation_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_tools.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_evaluation.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_evaluation.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/offline_eval_map_corloc_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/tf_example_parser_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_tools_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/tf_example_parser.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_metrics.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation_utils.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_metrics_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_evaluation.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_tools.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation_utils_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation_utils.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_evaluation_test.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/io_utils.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/offline_eval_map_corloc.py -> build/bdist.linux-x86_64/egg/object_detection/metrics
# creating build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_nas_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_fpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_mobilenet_v2_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobiledet_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_fpn_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_resnet_v2_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_efficientnet_bifpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_mobilenet_v2_fpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_resnet_v1_fpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_edgetpu_feature_extractor_testbase.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/feature_map_generators.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_pnas_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_nas_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobiledet_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_pnas_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_v1_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_ppn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_efficientnet_bifpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_resnet_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_fpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/bidirectional_feature_pyramid_generators.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_edgetpu_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_ppn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_resnet_v1_fpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_mobilenet_v2_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_v2_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_inception_v2_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_resnet_v2_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_feature_extractor_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_inception_v3_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_mobilenet_v1_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_edgetpu_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/embedded_ssd_mobilenet_v1_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_v2_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_resnet_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_inception_v2_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_hourglass_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/center_net_hourglass_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v1_fpn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/feature_map_generators_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_v1_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/bidirectional_feature_pyramid_generators_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_v1_fpn_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_inception_v3_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/faster_rcnn_resnet_keras_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_pnasnet_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_fpn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_ppn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_fpn_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_fpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_fpn_feature_extractor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v3_feature_extractor_testbase.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_fpn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_ppn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_fpn_keras_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_mnasfpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v3_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_fpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_fpn_feature_extractor_testbase.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_pnasnet_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_resnet_v1_ppn_feature_extractor_testbase.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_mnasfpn_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v3_feature_extractor_tf1_test.py -> build/bdist.linux-x86_64/egg/object_detection/models
# copying build/lib/object_detection/models/ssd_mobilenet_v2_fpn_feature_extractor.py -> build/bdist.linux-x86_64/egg/object_detection/models
# creating build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/mobilenet_v1_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/test_utils.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/mobilenet_v1.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/hourglass_network.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/mobilenet_v2.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/hourglass_network_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/resnet_v1.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/mobilenet_v2_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/__init__.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/resnet_v1_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/model_utils.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/inception_resnet_v2_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/inception_resnet_v2.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# copying build/lib/object_detection/models/keras_models/convert_keras_models.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models
# creating build/bdist.linux-x86_64/egg/object_detection/models/keras_models/base_models
# copying build/lib/object_detection/models/keras_models/base_models/original_mobilenet_v2.py -> build/bdist.linux-x86_64/egg/object_detection/models/keras_models/base_models
# creating build/bdist.linux-x86_64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/convolutional_keras_box_predictor_tf2_test.py -> build/bdist.linux-x86_64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_box_predictor.py -> build/bdist.linux-x86_64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_keras_box_predictor.py -> build/bdist.linux-x86_64/egg/object_detection/predictors
# ...
# byte-compiling build/bdist.linux-x86_64/egg/nets/mobilenet/mobilenet.py to mobilenet.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/mobilenet/mobilenet_v2_test.py to mobilenet_v2_test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/nasnet_utils.py to nasnet_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/nasnet_test.py to nasnet_test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/pnasnet.py to pnasnet.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/pnasnet_test.py to pnasnet_test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/nasnet_utils_test.py to nasnet_utils_test.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/nets/nasnet/nasnet.py to nasnet.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/preprocessing_factory.py to preprocessing_factory.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/inception_preprocessing.py to inception_preprocessing.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/lenet_preprocessing.py to lenet_preprocessing.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/vgg_preprocessing.py to vgg_preprocessing.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/preprocessing/cifarnet_preprocessing.py to cifarnet_preprocessing.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/object_detection-0.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing object_detection-0.1-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/object_detection-0.1-py3.7.egg
# Extracting object_detection-0.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding object-detection 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/object_detection-0.1-py3.7.egg
# Processing dependencies for object-detection==0.1
# Searching for tf-models-official
# Reading https://pypi.org/simple/tf-models-official/
# Downloading https://files.pythonhosted.org/packages/d7/43/3e0a554fc77a62059a95d183e6d1e33dc56e984ebba2193d9dfff4a03533/tf_models_official-2.5.1-py2.py3-none-any.whl#sha256=4992b6c3722e6382cc4c35702106d10ee491e21339fa067976ddb0b5aaa1a652
# Best match: tf-models-official 2.5.1
# Processing tf_models_official-2.5.1-py2.py3-none-any.whl
# Installing tf_models_official-2.5.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding tf-models-official 2.5.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/tf_models_official-2.5.1-py3.7.egg
# Searching for apache-beam
# Reading https://pypi.org/simple/apache-beam/
# Downloading https://files.pythonhosted.org/packages/da/7d/ec8abb1366b5171bf861f176b51d1be3ec88f5398c0b5f3659a1a355d453/apache_beam-2.31.0-cp37-cp37m-manylinux1_x86_64.whl#sha256=7306ac79c5c2ebb4715be49b0051a23f01b26e8600c5e5f299dd9dd61c5daf05
# Best match: apache-beam 2.31.0
# Processing apache_beam-2.31.0-cp37-cp37m-manylinux1_x86_64.whl
# Installing apache_beam-2.31.0-cp37-cp37m-manylinux1_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding apache-beam 2.31.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/apache_beam-2.31.0-py3.7-linux-x86_64.egg
# Searching for avro-python3
# Reading https://pypi.org/simple/avro-python3/
# Downloading https://files.pythonhosted.org/packages/cc/97/7a6970380ca8db9139a3cc0b0e3e0dd3e4bc584fb3644e1d06e71e1a55f0/avro-python3-1.10.2.tar.gz#sha256=3b63f24e6b04368c3e4a6f923f484be0230d821aad65ac36108edbff29e9aaab
# Best match: avro-python3 1.10.2
# Processing avro-python3-1.10.2.tar.gz
# Writing /tmp/easy_install-0rpwxvh3/avro-python3-1.10.2/setup.cfg
# Running avro-python3-1.10.2/setup.py -q bdist_egg --dist-dir /tmp/easy_install-0rpwxvh3/avro-python3-1.10.2/egg-dist-tmp-t4o3aamh
# Moving avro_python3-1.10.2-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding avro-python3 1.10.2 to easy-install.pth file
# Installing avro script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/avro_python3-1.10.2-py3.7.egg
# Searching for tensorflow-model-optimization>=0.4.1
# Reading https://pypi.org/simple/tensorflow-model-optimization/
# Downloading https://files.pythonhosted.org/packages/78/8f/f6969dc64709c5c5e22cfd7057a83adbc927e6855a431b234168222cbf03/tensorflow_model_optimization-0.6.0-py2.py3-none-any.whl#sha256=09acf6023ef1efed3a0403cd3c0ed343767765312dc6a8a4ae58626821823e2a
# Best match: tensorflow-model-optimization 0.6.0
# Processing tensorflow_model_optimization-0.6.0-py2.py3-none-any.whl
# Installing tensorflow_model_optimization-0.6.0-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding tensorflow-model-optimization 0.6.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/tensorflow_model_optimization-0.6.0-py3.7.egg
# Searching for tensorflow-addons
# Reading https://pypi.org/simple/tensorflow-addons/
# Downloading https://files.pythonhosted.org/packages/66/4b/e893d194e626c24b3df2253066aa418f46a432fdb68250cde14bf9bb0700/tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl#sha256=53ba098b500aa9b1695ad0534c8878fe15f39cc43879d2025e0ab2ded62643d6
# Best match: tensorflow-addons 0.13.0
# Processing tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl
# Installing tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding tensorflow-addons 0.13.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/tensorflow_addons-0.13.0-py3.7-linux-x86_64.egg
# Searching for seqeval
# Reading https://pypi.org/simple/seqeval/
# Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz#sha256=f28e97c3ab96d6fcd32b648f6438ff2e09cfba87f05939da9b3970713ec56e6f
# Best match: seqeval 1.2.2
# Processing seqeval-1.2.2.tar.gz
# Writing /tmp/easy_install-uu1g39gt/seqeval-1.2.2/setup.cfg
# Running seqeval-1.2.2/setup.py -q bdist_egg --dist-dir /tmp/easy_install-uu1g39gt/seqeval-1.2.2/egg-dist-tmp-4cohthbi
# Moving seqeval-1.2.2-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding seqeval 1.2.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/seqeval-1.2.2-py3.7.egg
# Searching for sentencepiece
# Reading https://pypi.org/simple/sentencepiece/
# Downloading https://files.pythonhosted.org/packages/ac/aa/1437691b0c7c83086ebb79ce2da16e00bef024f24fec2a5161c35476f499/sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=d954d25a8705f972e8bfc1dea5464d7e697dd6f4ade092f1a487387e6d6c829a
# Best match: sentencepiece 0.1.96
# Processing sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding sentencepiece 0.1.96 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/sentencepiece-0.1.96-py3.7-linux-x86_64.egg
# Searching for sacrebleu
# Reading https://pypi.org/simple/sacrebleu/
# Downloading https://files.pythonhosted.org/packages/7e/57/0c7ca4e31a126189dab99c19951910bd081dea5bbd25f24b77107750eae7/sacrebleu-1.5.1-py3-none-any.whl#sha256=fbe54fcc7f4e370c9ded0c7cb9bbdadabc020bcde9217daea043b4906b962fdc
# Best match: sacrebleu 1.5.1
# Processing sacrebleu-1.5.1-py3-none-any.whl
# Installing sacrebleu-1.5.1-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding sacrebleu 1.5.1 to easy-install.pth file
# Installing sacrebleu script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/sacrebleu-1.5.1-py3.7.egg
# Searching for pyyaml>=5.1
# Reading https://pypi.org/simple/pyyaml/
# Downloading https://files.pythonhosted.org/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl#sha256=e1d4970ea66be07ae37a3c2e48b5ec63f7ba6804bdddfdbd3cfd954d25a82e63
# Best match: PyYAML 5.4.1
# Processing PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl
# Installing PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding PyYAML 5.4.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/PyYAML-5.4.1-py3.7-linux-x86_64.egg
# Searching for py-cpuinfo>=3.3.0
# Reading https://pypi.org/simple/py-cpuinfo/
# Downloading https://files.pythonhosted.org/packages/e6/ba/77120e44cbe9719152415b97d5bfb29f4053ee987d6cb63f55ce7d50fadc/py-cpuinfo-8.0.0.tar.gz#sha256=5f269be0e08e33fd959de96b34cd4aeeeacac014dd8305f70eb28d06de2345c5
# Best match: py-cpuinfo 8.0.0
# Processing py-cpuinfo-8.0.0.tar.gz
# Writing /tmp/easy_install-l701p26a/py-cpuinfo-8.0.0/setup.cfg
# Running py-cpuinfo-8.0.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-l701p26a/py-cpuinfo-8.0.0/egg-dist-tmp-kkvjfih1
# creating /usr/local/lib/python3.7/dist-packages/py_cpuinfo-8.0.0-py3.7.egg
# Extracting py_cpuinfo-8.0.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding py-cpuinfo 8.0.0 to easy-install.pth file
# Installing cpuinfo script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/py_cpuinfo-8.0.0-py3.7.egg
# Searching for opencv-python-headless
# Reading https://pypi.org/simple/opencv-python-headless/
# Downloading https://files.pythonhosted.org/packages/74/53/48036b28d46c1ed45ec655ae7ef6caab45e4452834d63817fdef64f333a3/opencv_python_headless-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl#sha256=c54ad51bfc4623de287bd68f14f481f72300bd16a2d9e14850c1ef1a2dfc7dca
# Best match: opencv-python-headless 4.5.3.56
# Processing opencv_python_headless-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl
# Installing opencv_python_headless-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding opencv-python-headless 4.5.3.56 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.3.56-py3.7-linux-x86_64.egg
# Searching for requests<3.0.0,>=2.24.0
# Reading https://pypi.org/simple/requests/
# Downloading https://files.pythonhosted.org/packages/92/96/144f70b972a9c0eabbd4391ef93ccd49d0f2747f4f6a2a2738e99e5adc65/requests-2.26.0-py2.py3-none-any.whl#sha256=6c1246513ecd5ecd4528a0906f910e8f0f9c6b8ec72030dc9fd154dc1a6efd24
# Best match: requests 2.26.0
# Processing requests-2.26.0-py2.py3-none-any.whl
# Installing requests-2.26.0-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding requests 2.26.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/requests-2.26.0-py3.7.egg
# Searching for hdfs<3.0.0,>=2.1.0
# Reading https://pypi.org/simple/hdfs/
# Downloading https://files.pythonhosted.org/packages/08/f7/4c3fad73123a24d7394b6f40d1ec9c1cbf2e921cfea1797216ffd0a51fb1/hdfs-2.6.0-py3-none-any.whl#sha256=05912125cfc68075387f271654dac185dc1aba8b347519f6a14d1395e39d7749
# Best match: hdfs 2.6.0
# Processing hdfs-2.6.0-py3-none-any.whl
# Installing hdfs-2.6.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding hdfs 2.6.0 to easy-install.pth file
# Installing hdfscli script to /usr/local/bin
# Installing hdfscli-avro script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/hdfs-2.6.0-py3.7.egg
# Searching for future<1.0.0,>=0.18.2
# Reading https://pypi.org/simple/future/
# Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz#sha256=b1bead90b70cf6ec3f0710ae53a525360fa360d306a86583adc6bf83a4db537d
# Best match: future 0.18.2
# Processing future-0.18.2.tar.gz
# Writing /tmp/easy_install-o0tfq7ij/future-0.18.2/setup.cfg
# Running future-0.18.2/setup.py -q bdist_egg --dist-dir /tmp/easy_install-o0tfq7ij/future-0.18.2/egg-dist-tmp-c5foy6oy
# creating /usr/local/lib/python3.7/dist-packages/future-0.18.2-py3.7.egg
# Extracting future-0.18.2-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding future 0.18.2 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/future-0.18.2-py3.7.egg
# Searching for fastavro<2,>=0.21.4
# Reading https://pypi.org/simple/fastavro/
# Downloading https://files.pythonhosted.org/packages/09/db/8c8eda2864d1c1330a60ac362728d4e02c4ef60c7ad9fd87de24fc069848/fastavro-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=b53816eec734ca34518c7e748d6d538aca0d3c0111ec726ad9808a098bfdd209
# Best match: fastavro 1.4.4
# Processing fastavro-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing fastavro-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding fastavro 1.4.4 to easy-install.pth file
# Installing fastavro script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/fastavro-1.4.4-py3.7-linux-x86_64.egg
# Searching for dill<0.3.2,>=0.3.1.1
# Reading https://pypi.org/simple/dill/
# Downloading https://files.pythonhosted.org/packages/c7/11/345f3173809cea7f1a193bfbf02403fff250a3360e0e118a1630985e547d/dill-0.3.1.1.tar.gz#sha256=42d8ef819367516592a825746a18073ced42ca169ab1f5f4044134703e7a049c
# Best match: dill 0.3.1.1
# Processing dill-0.3.1.1.tar.gz
# Writing /tmp/easy_install-rkaxzeyg/dill-0.3.1.1/setup.cfg
# Running dill-0.3.1.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-rkaxzeyg/dill-0.3.1.1/egg-dist-tmp-jymmhc8c
# creating /usr/local/lib/python3.7/dist-packages/dill-0.3.1.1-py3.7.egg
# Extracting dill-0.3.1.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding dill 0.3.1.1 to easy-install.pth file
# Installing undill script to /usr/local/bin
# Installing get_objgraph script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/dill-0.3.1.1-py3.7.egg
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-37: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-37: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-37: module MAY be using inspect.stack
# zip_safe flag not set; analyzing archive contents...
# zip_safe flag not set; analyzing archive contents...
# cpuinfo.__pycache__.cpuinfo.cpython-37: module references __file__
# cpuinfo.__pycache__.cpuinfo.cpython-37: module MAY be using inspect.stack
# cpuinfo.__pycache__.cpuinfo.cpython-37: module MAY be using inspect.trace
# warning: no files found matching '*.au' under directory 'tests'
# warning: no files found matching '*.gif' under directory 'tests'
# warning: no files found matching '*.txt' under directory 'tests'
# zip_safe flag not set; analyzing archive contents...
# future.backports.test.__pycache__.ssl_servers.cpython-37: module references __file__
# future.backports.test.__pycache__.support.cpython-37: module references __file__
# future.standard_library.__pycache__.__init__.cpython-37: module references __file__
# future.standard_library.__pycache__.__init__.cpython-37: module references __path__
# future.utils.__pycache__.__init__.cpython-37: module MAY be using inspect.stack
# past.builtins.__pycache__.misc.cpython-37: module MAY be using inspect.stack
# past.translation.__pycache__.__init__.cpython-37: module references __file__
# past.translation.__pycache__.__init__.cpython-37: module references __path__
# error: avro-python3 1.10.2 is installed but avro-python3!=1.9.2,<1.10.0,>=1.8.1 is required by {'apache-beam'}

# %%
# %%bash
# python -m pip install .
# Out:
# Processing /content/gdrive/My Drive/TensorFlow/models/research
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.7/dist-packages/avro_python3-1.10.2-py3.7.egg (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.7/dist-packages/apache_beam-2.31.0-py3.7-linux-x86_64.egg (from object-detection==0.1) (2.31.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.23)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.2)
# Requirement already satisfied: lvis in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.1.5)
# Requirement already satisfied: tf-models-official in /usr/local/lib/python3.7/dist-packages/tf_models_official-2.5.1-py3.7.egg (from object-detection==0.1) (2.5.1)
# Collecting avro-python3
#   Downloading avro-python3-1.9.2.1.tar.gz (37 kB)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Requirement already satisfied: fastavro<2,>=0.21.4 in /usr/local/lib/python3.7/dist-packages/fastavro-1.4.4-py3.7-linux-x86_64.egg (from apache-beam->object-detection==0.1) (1.4.4)
# Collecting future<1.0.0,>=0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: grpcio<2,>=1.29.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.34.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages/hdfs-2.6.0-py3.7.egg (from apache-beam->object-detection==0.1) (2.6.0)
# Requirement already satisfied: httplib2<0.20.0,>=0.8 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (0.17.4)
# Requirement already satisfied: numpy<1.21.0,>=1.14.3 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.19.5)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (4.1.3)
# Requirement already satisfied: protobuf<4,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.17.3)
# Requirement already satisfied: pyarrow<5.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.0.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.11.4)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (2.8.1)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (2018.9)
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Requirement already satisfied: typing-extensions<3.8.0,>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.7.4.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (4.7.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot<2,>=1.2.0->apache-beam->object-detection==0.1) (2.4.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (1.24.3)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.10.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.3.1)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools->object-detection==0.1) (57.2.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (1.12.8)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (1.5.12)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.3.56-py3.7-linux-x86_64.egg (from tf-models-official->object-detection==0.1) (4.5.3.56)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (5.4.8)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.7/dist-packages/py_cpuinfo-8.0.0-py3.7.egg (from tf-models-official->object-detection==0.1) (8.0.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages/sacrebleu-1.5.1-py3.7.egg (from tf-models-official->object-detection==0.1) (1.5.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages/sentencepiece-0.1.96-py3.7-linux-x86_64.egg (from tf-models-official->object-detection==0.1) (0.1.96)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages/seqeval-1.2.2-py3.7.egg (from tf-models-official->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages/tensorflow_addons-0.13.0-py3.7-linux-x86_64.egg (from tf-models-official->object-detection==0.1) (0.13.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (4.0.1)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (0.12.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.7/dist-packages/tensorflow_model_optimization-0.6.0-py3.7.egg (from tf-models-official->object-detection==0.1) (0.6.0)
# Requirement already satisfied: tensorflow>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official->object-detection==0.1) (2.5.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.26.3)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.32.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (21.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (4.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official->object-detection==0.1) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official->object-detection==0.1) (5.0.2)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.12.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (2.5.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.12)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.36.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.6.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (2.5.0.dev2021032900)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.1.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (3.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (4.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (3.1.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official->object-detection==0.1) (0.1.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.5.0->tf-models-official->object-detection==0.1) (3.5.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official->object-detection==0.1) (1.3)
# Collecting portalocker==2.0.0
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official->object-detection==0.1) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official->object-detection==0.1) (1.0.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official->object-detection==0.1) (2.7.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (5.2.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (1.1.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (21.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (2.3)
# Building wheels for collected packages: object-detection, avro-python3, dill, future
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=21856155 sha256=3cda01ca80d67b0bc6d2118801c663bb2efbbce5f9eefa79914052ce8a09d760
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hnuoc06k/wheels/2d/dd/8d/7f002eb6552302efe58eb9724989cba886f69f5a4d6164b5eb
#   Building wheel for avro-python3 (setup.py): started
#   Building wheel for avro-python3 (setup.py): finished with status 'done'
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=073514c988ab71ad60b0ecc8c725782a3812aa47d6e8cac4dce3beea5d06f293
#   Stored in directory: /root/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=f790c531d2023ebe9944e4df3eee2b9d11d7562ff1759bde5e8d2058a6ae67ef
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=92f3df4daeec4573f0e67d56c9b836fe57c3f3af509d12d7fa05125cef5c51c3
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built object-detection avro-python3 dill future
# Installing collected packages: requests, portalocker, future, dill, pyyaml, avro-python3, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: avro-python3
#     Found existing installation: avro-python3 1.10.2
#     Uninstalling avro-python3-1.10.2:
#       Successfully uninstalled avro-python3-1.10.2
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed avro-python3-1.9.2.1 dill-0.3.1.1 future-0.18.2 object-detection-0.1 portalocker-2.0.0 pyyaml-5.4.1 requests-2.26.0
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
# %cd '/content/gdrive/My Drive/TensorFlow/models/research/object_detection/builders/'
# !python model_builder_tf2_test.py
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
print('Done')
# Out:
# /content/gdrive/My Drive/TensorFlow/models/research/object_detection/builders
# 2021-07-31 08:57:43.522638: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Running tests under Python 3.7.11: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-07-31 08:57:51.391721: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-31 08:57:51.463099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.463736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-31 08:57:51.463783: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-31 08:57:51.543491: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-31 08:57:51.543606: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-31 08:57:51.684961: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-07-31 08:57:51.722992: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-07-31 08:57:51.944594: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-07-31 08:57:51.958664: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-07-31 08:57:51.963460: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-31 08:57:51.963631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.964312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.967684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-31 08:57:51.968284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.968833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-31 08:57:51.968914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.969499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:51.970012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-31 08:57:51.972842: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-31 08:57:54.762232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-31 08:57:54.762285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-31 08:57:54.762299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-31 08:57:54.762481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:54.763091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:54.763678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:57:54.764213: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-07-31 08:57:54.764259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15433 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# W0731 08:57:54.991064 139852404680576 model_builder.py:1085] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 3.85s
# I0731 08:57:55.228672 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 3.85s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.56s
# I0731 08:57:55.787520 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.56s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# I0731 08:57:56.033026 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# I0731 08:57:56.254570 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# W0731 08:57:56.256670 139852404680576 mobilenet_v2.py:296] `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.84s
# I0731 08:57:58.099666 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.84s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0731 08:57:58.100643 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0731 08:57:58.119845 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0731 08:57:58.133645 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0731 08:57:58.148617 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# I0731 08:57:58.236477 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# I0731 08:57:58.320456 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# I0731 08:57:58.415255 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# I0731 08:57:58.502355 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# I0731 08:57:58.597476 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0731 08:57:58.622418 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0731 08:57:58.783806 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0731 08:57:58.783974 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I0731 08:57:58.784050 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 3
# I0731 08:57:58.785965 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:57:58.800168 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:57:58.800270 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:57:58.851536 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:57:58.851689 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:57:58.978809 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:57:58.978972 139852404680576 efficientnet_model.py:147] round_filter input=40 output=40
# I0731 08:57:59.101447 139852404680576 efficientnet_model.py:147] round_filter input=40 output=40
# I0731 08:57:59.101620 139852404680576 efficientnet_model.py:147] round_filter input=80 output=80
# I0731 08:57:59.414413 139852404680576 efficientnet_model.py:147] round_filter input=80 output=80
# I0731 08:57:59.414583 139852404680576 efficientnet_model.py:147] round_filter input=112 output=112
# I0731 08:57:59.607927 139852404680576 efficientnet_model.py:147] round_filter input=112 output=112
# I0731 08:57:59.608105 139852404680576 efficientnet_model.py:147] round_filter input=192 output=192
# I0731 08:57:59.860751 139852404680576 efficientnet_model.py:147] round_filter input=192 output=192
# I0731 08:57:59.860917 139852404680576 efficientnet_model.py:147] round_filter input=320 output=320
# I0731 08:57:59.922647 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0731 08:57:59.950901 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:57:59.997551 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0731 08:57:59.997716 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 88
# I0731 08:57:59.997787 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 4
# I0731 08:57:59.999296 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:58:00.013752 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:58:00.013875 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:58:00.112101 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:58:00.112281 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:58:00.300677 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:58:00.300850 139852404680576 efficientnet_model.py:147] round_filter input=40 output=40
# I0731 08:58:00.494408 139852404680576 efficientnet_model.py:147] round_filter input=40 output=40
# I0731 08:58:00.494576 139852404680576 efficientnet_model.py:147] round_filter input=80 output=80
# I0731 08:58:00.762257 139852404680576 efficientnet_model.py:147] round_filter input=80 output=80
# I0731 08:58:00.762422 139852404680576 efficientnet_model.py:147] round_filter input=112 output=112
# I0731 08:58:01.010159 139852404680576 efficientnet_model.py:147] round_filter input=112 output=112
# I0731 08:58:01.010333 139852404680576 efficientnet_model.py:147] round_filter input=192 output=192
# I0731 08:58:01.334753 139852404680576 efficientnet_model.py:147] round_filter input=192 output=192
# I0731 08:58:01.334924 139852404680576 efficientnet_model.py:147] round_filter input=320 output=320
# I0731 08:58:01.459249 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0731 08:58:01.483312 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:01.543168 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0731 08:58:01.543329 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 112
# I0731 08:58:01.543399 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 5
# I0731 08:58:01.544881 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:58:01.566590 139852404680576 efficientnet_model.py:147] round_filter input=32 output=32
# I0731 08:58:01.566733 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:58:01.665788 139852404680576 efficientnet_model.py:147] round_filter input=16 output=16
# I0731 08:58:01.665952 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:58:01.981830 139852404680576 efficientnet_model.py:147] round_filter input=24 output=24
# I0731 08:58:01.982010 139852404680576 efficientnet_model.py:147] round_filter input=40 output=48
# I0731 08:58:02.172923 139852404680576 efficientnet_model.py:147] round_filter input=40 output=48
# I0731 08:58:02.173101 139852404680576 efficientnet_model.py:147] round_filter input=80 output=88
# I0731 08:58:02.438533 139852404680576 efficientnet_model.py:147] round_filter input=80 output=88
# I0731 08:58:02.438712 139852404680576 efficientnet_model.py:147] round_filter input=112 output=120
# I0731 08:58:02.699772 139852404680576 efficientnet_model.py:147] round_filter input=112 output=120
# I0731 08:58:02.699961 139852404680576 efficientnet_model.py:147] round_filter input=192 output=208
# I0731 08:58:03.023114 139852404680576 efficientnet_model.py:147] round_filter input=192 output=208
# I0731 08:58:03.023309 139852404680576 efficientnet_model.py:147] round_filter input=320 output=352
# I0731 08:58:03.150932 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=1408
# I0731 08:58:03.176689 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:03.235341 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0731 08:58:03.235508 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 160
# I0731 08:58:03.235574 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 6
# I0731 08:58:03.237331 139852404680576 efficientnet_model.py:147] round_filter input=32 output=40
# I0731 08:58:03.250741 139852404680576 efficientnet_model.py:147] round_filter input=32 output=40
# I0731 08:58:03.250894 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:03.355772 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:03.355970 139852404680576 efficientnet_model.py:147] round_filter input=24 output=32
# I0731 08:58:03.547344 139852404680576 efficientnet_model.py:147] round_filter input=24 output=32
# I0731 08:58:03.547520 139852404680576 efficientnet_model.py:147] round_filter input=40 output=48
# I0731 08:58:03.747051 139852404680576 efficientnet_model.py:147] round_filter input=40 output=48
# I0731 08:58:03.747235 139852404680576 efficientnet_model.py:147] round_filter input=80 output=96
# I0731 08:58:04.078852 139852404680576 efficientnet_model.py:147] round_filter input=80 output=96
# I0731 08:58:04.079041 139852404680576 efficientnet_model.py:147] round_filter input=112 output=136
# I0731 08:58:04.410684 139852404680576 efficientnet_model.py:147] round_filter input=112 output=136
# I0731 08:58:04.410860 139852404680576 efficientnet_model.py:147] round_filter input=192 output=232
# I0731 08:58:04.806212 139852404680576 efficientnet_model.py:147] round_filter input=192 output=232
# I0731 08:58:04.806389 139852404680576 efficientnet_model.py:147] round_filter input=320 output=384
# I0731 08:58:05.090991 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=1536
# I0731 08:58:05.119203 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:05.181987 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0731 08:58:05.182192 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 224
# I0731 08:58:05.182266 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0731 08:58:05.183803 139852404680576 efficientnet_model.py:147] round_filter input=32 output=48
# I0731 08:58:05.198279 139852404680576 efficientnet_model.py:147] round_filter input=32 output=48
# I0731 08:58:05.198394 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:05.299671 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:05.299839 139852404680576 efficientnet_model.py:147] round_filter input=24 output=32
# I0731 08:58:05.554205 139852404680576 efficientnet_model.py:147] round_filter input=24 output=32
# I0731 08:58:05.554374 139852404680576 efficientnet_model.py:147] round_filter input=40 output=56
# I0731 08:58:05.810001 139852404680576 efficientnet_model.py:147] round_filter input=40 output=56
# I0731 08:58:05.810180 139852404680576 efficientnet_model.py:147] round_filter input=80 output=112
# I0731 08:58:06.193884 139852404680576 efficientnet_model.py:147] round_filter input=80 output=112
# I0731 08:58:06.194087 139852404680576 efficientnet_model.py:147] round_filter input=112 output=160
# I0731 08:58:06.581804 139852404680576 efficientnet_model.py:147] round_filter input=112 output=160
# I0731 08:58:06.581999 139852404680576 efficientnet_model.py:147] round_filter input=192 output=272
# I0731 08:58:07.097137 139852404680576 efficientnet_model.py:147] round_filter input=192 output=272
# I0731 08:58:07.097336 139852404680576 efficientnet_model.py:147] round_filter input=320 output=448
# I0731 08:58:07.236260 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=1792
# I0731 08:58:07.260151 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:07.334844 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0731 08:58:07.335015 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 288
# I0731 08:58:07.335093 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0731 08:58:07.336680 139852404680576 efficientnet_model.py:147] round_filter input=32 output=48
# I0731 08:58:07.349773 139852404680576 efficientnet_model.py:147] round_filter input=32 output=48
# I0731 08:58:07.349906 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:07.504444 139852404680576 efficientnet_model.py:147] round_filter input=16 output=24
# I0731 08:58:07.504625 139852404680576 efficientnet_model.py:147] round_filter input=24 output=40
# I0731 08:58:07.825084 139852404680576 efficientnet_model.py:147] round_filter input=24 output=40
# I0731 08:58:07.825263 139852404680576 efficientnet_model.py:147] round_filter input=40 output=64
# I0731 08:58:08.349852 139852404680576 efficientnet_model.py:147] round_filter input=40 output=64
# I0731 08:58:08.350041 139852404680576 efficientnet_model.py:147] round_filter input=80 output=128
# I0731 08:58:08.802706 139852404680576 efficientnet_model.py:147] round_filter input=80 output=128
# I0731 08:58:08.802881 139852404680576 efficientnet_model.py:147] round_filter input=112 output=176
# I0731 08:58:09.255622 139852404680576 efficientnet_model.py:147] round_filter input=112 output=176
# I0731 08:58:09.255795 139852404680576 efficientnet_model.py:147] round_filter input=192 output=304
# I0731 08:58:09.838812 139852404680576 efficientnet_model.py:147] round_filter input=192 output=304
# I0731 08:58:09.838990 139852404680576 efficientnet_model.py:147] round_filter input=320 output=512
# I0731 08:58:10.027026 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=2048
# I0731 08:58:10.052603 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:10.140029 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0731 08:58:10.140207 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0731 08:58:10.140281 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0731 08:58:10.141806 139852404680576 efficientnet_model.py:147] round_filter input=32 output=56
# I0731 08:58:10.155044 139852404680576 efficientnet_model.py:147] round_filter input=32 output=56
# I0731 08:58:10.155168 139852404680576 efficientnet_model.py:147] round_filter input=16 output=32
# I0731 08:58:10.308106 139852404680576 efficientnet_model.py:147] round_filter input=16 output=32
# I0731 08:58:10.308290 139852404680576 efficientnet_model.py:147] round_filter input=24 output=40
# I0731 08:58:10.695276 139852404680576 efficientnet_model.py:147] round_filter input=24 output=40
# I0731 08:58:10.695447 139852404680576 efficientnet_model.py:147] round_filter input=40 output=72
# I0731 08:58:11.079706 139852404680576 efficientnet_model.py:147] round_filter input=40 output=72
# I0731 08:58:11.079881 139852404680576 efficientnet_model.py:147] round_filter input=80 output=144
# I0731 08:58:11.614535 139852404680576 efficientnet_model.py:147] round_filter input=80 output=144
# I0731 08:58:11.614709 139852404680576 efficientnet_model.py:147] round_filter input=112 output=200
# I0731 08:58:12.306838 139852404680576 efficientnet_model.py:147] round_filter input=112 output=200
# I0731 08:58:12.307019 139852404680576 efficientnet_model.py:147] round_filter input=192 output=344
# I0731 08:58:13.009737 139852404680576 efficientnet_model.py:147] round_filter input=192 output=344
# I0731 08:58:13.009914 139852404680576 efficientnet_model.py:147] round_filter input=320 output=576
# I0731 08:58:13.201613 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0731 08:58:13.227262 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 08:58:13.322975 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0731 08:58:13.323197 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0731 08:58:13.323284 139852404680576 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0731 08:58:13.325006 139852404680576 efficientnet_model.py:147] round_filter input=32 output=64
# I0731 08:58:13.339825 139852404680576 efficientnet_model.py:147] round_filter input=32 output=64
# I0731 08:58:13.339944 139852404680576 efficientnet_model.py:147] round_filter input=16 output=32
# I0731 08:58:13.546950 139852404680576 efficientnet_model.py:147] round_filter input=16 output=32
# I0731 08:58:13.547123 139852404680576 efficientnet_model.py:147] round_filter input=24 output=48
# I0731 08:58:14.000206 139852404680576 efficientnet_model.py:147] round_filter input=24 output=48
# I0731 08:58:14.000386 139852404680576 efficientnet_model.py:147] round_filter input=40 output=80
# I0731 08:58:14.458123 139852404680576 efficientnet_model.py:147] round_filter input=40 output=80
# I0731 08:58:14.458308 139852404680576 efficientnet_model.py:147] round_filter input=80 output=160
# I0731 08:58:15.102454 139852404680576 efficientnet_model.py:147] round_filter input=80 output=160
# I0731 08:58:15.102638 139852404680576 efficientnet_model.py:147] round_filter input=112 output=224
# I0731 08:58:15.967801 139852404680576 efficientnet_model.py:147] round_filter input=112 output=224
# I0731 08:58:15.968004 139852404680576 efficientnet_model.py:147] round_filter input=192 output=384
# I0731 08:58:16.862235 139852404680576 efficientnet_model.py:147] round_filter input=192 output=384
# I0731 08:58:16.862410 139852404680576 efficientnet_model.py:147] round_filter input=320 output=640
# I0731 08:58:17.132976 139852404680576 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0731 08:58:17.171239 139852404680576 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 18.67s
# I0731 08:58:17.293781 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 18.67s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0731 08:58:17.300248 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0731 08:58:17.301854 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0731 08:58:17.302341 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0731 08:58:17.303760 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0731 08:58:17.305134 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0731 08:58:17.305589 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0731 08:58:17.306546 139852404680576 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 25.929s
#
# OK (skipped=1)
# Done

# %% [markdown]
# ### GENERATE THE TRAINING AND TEST TF RECORDS

# %%
#cd into preprocessing directory
# %cd '/content/gdrive/My Drive/TensorFlow/scripts/preprocessing'
#run the cell to generate test.record and train.record
# !python generate_tfrecord.py -x '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/FinalTrainImages' -l '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/label_map.pbtxt' -o '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/train.record'
# !python generate_tfrecord.py -x '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/test' -l '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/label_map.pbtxt' -o '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/test.record'
# Out:
# /content/gdrive/My Drive/TensorFlow/scripts/preprocessing
# Successfully created the TFRecord file: /content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/train.record
# Successfully created the TFRecord file: /content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/test.record

# %%
#cd into training_demo
# %cd '/content/gdrive/My Drive/TensorFlow/workspace/training_demo'
#start the Tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=models/my_ssd_resnet50_fpn_cl_augmented

# %%
# %cd '/content/gdrive/My Drive/TensorFlow/workspace/training_demo'
# Out:
# /content/gdrive/My Drive/TensorFlow/workspace/training_demo

# %% [markdown]
# ### TRAINING

# %%
# !python model_main_tf2.py --model_dir=models/my_ssd_resnet50_fpn_cl_augmented --pipeline_config_path=models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config
# Out:
# Streaming output truncated to the last 5000 lines.
#  'Loss/regularization_loss': 0.09700596,
#  'Loss/total_loss': 0.28236407,
#  'learning_rate': 0.032832485}
# I0622 18:38:46.614677 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1437807,
#  'Loss/localization_loss': 0.041577414,
#  'Loss/regularization_loss': 0.09700596,
#  'Loss/total_loss': 0.28236407,
#  'learning_rate': 0.032832485}
# INFO:tensorflow:Step 8500 per-step time 0.554s
# I0622 18:39:41.976707 140614804805504 model_lib_v2.py:699] Step 8500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.23162156,
#  'Loss/localization_loss': 0.04112708,
#  'Loss/regularization_loss': 0.09628575,
#  'Loss/total_loss': 0.3690344,
#  'learning_rate': 0.032621756}
# I0622 18:39:41.977010 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.23162156,
#  'Loss/localization_loss': 0.04112708,
#  'Loss/regularization_loss': 0.09628575,
#  'Loss/total_loss': 0.3690344,
#  'learning_rate': 0.032621756}
# INFO:tensorflow:Step 8600 per-step time 0.554s
# I0622 18:40:37.335992 140614804805504 model_lib_v2.py:699] Step 8600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.1469265,
#  'Loss/localization_loss': 0.038923167,
#  'Loss/regularization_loss': 0.09551081,
#  'Loss/total_loss': 0.28136048,
#  'learning_rate': 0.032408677}
# I0622 18:40:37.336291 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1469265,
#  'Loss/localization_loss': 0.038923167,
#  'Loss/regularization_loss': 0.09551081,
#  'Loss/total_loss': 0.28136048,
#  'learning_rate': 0.032408677}
# INFO:tensorflow:Step 8700 per-step time 0.554s
# I0622 18:41:32.739756 140614804805504 model_lib_v2.py:699] Step 8700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.20703286,
#  'Loss/localization_loss': 0.06616561,
#  'Loss/regularization_loss': 0.09513854,
#  'Loss/total_loss': 0.36833704,
#  'learning_rate': 0.032193277}
# I0622 18:41:32.740051 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.20703286,
#  'Loss/localization_loss': 0.06616561,
#  'Loss/regularization_loss': 0.09513854,
#  'Loss/total_loss': 0.36833704,
#  'learning_rate': 0.032193277}
# INFO:tensorflow:Step 8800 per-step time 0.553s
# I0622 18:42:28.049422 140614804805504 model_lib_v2.py:699] Step 8800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.15441947,
#  'Loss/localization_loss': 0.029453617,
#  'Loss/regularization_loss': 0.094929345,
#  'Loss/total_loss': 0.27880242,
#  'learning_rate': 0.03197561}
# I0622 18:42:28.049740 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15441947,
#  'Loss/localization_loss': 0.029453617,
#  'Loss/regularization_loss': 0.094929345,
#  'Loss/total_loss': 0.27880242,
#  'learning_rate': 0.03197561}
# INFO:tensorflow:Step 8900 per-step time 0.554s
# I0622 18:43:23.409229 140614804805504 model_lib_v2.py:699] Step 8900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.21771234,
#  'Loss/localization_loss': 0.054909606,
#  'Loss/regularization_loss': 0.09413598,
#  'Loss/total_loss': 0.36675793,
#  'learning_rate': 0.031755704}
# I0622 18:43:23.409532 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.21771234,
#  'Loss/localization_loss': 0.054909606,
#  'Loss/regularization_loss': 0.09413598,
#  'Loss/total_loss': 0.36675793,
#  'learning_rate': 0.031755704}
# INFO:tensorflow:Step 9000 per-step time 0.554s
# I0622 18:44:18.786138 140614804805504 model_lib_v2.py:699] Step 9000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.16239297,
#  'Loss/localization_loss': 0.034550607,
#  'Loss/regularization_loss': 0.09336283,
#  'Loss/total_loss': 0.29030642,
#  'learning_rate': 0.031533606}
# I0622 18:44:18.786461 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.16239297,
#  'Loss/localization_loss': 0.034550607,
#  'Loss/regularization_loss': 0.09336283,
#  'Loss/total_loss': 0.29030642,
#  'learning_rate': 0.031533606}
# INFO:tensorflow:Step 9100 per-step time 0.570s
# I0622 18:45:15.782084 140614804805504 model_lib_v2.py:699] Step 9100 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.1747041,
#  'Loss/localization_loss': 0.03806645,
#  'Loss/regularization_loss': 0.09268829,
#  'Loss/total_loss': 0.30545884,
#  'learning_rate': 0.031309355}
# I0622 18:45:15.782387 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1747041,
#  'Loss/localization_loss': 0.03806645,
#  'Loss/regularization_loss': 0.09268829,
#  'Loss/total_loss': 0.30545884,
#  'learning_rate': 0.031309355}
# INFO:tensorflow:Step 9200 per-step time 0.554s
# I0622 18:46:11.144714 140614804805504 model_lib_v2.py:699] Step 9200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.17343798,
#  'Loss/localization_loss': 0.020951139,
#  'Loss/regularization_loss': 0.092076465,
#  'Loss/total_loss': 0.2864656,
#  'learning_rate': 0.031082997}
# I0622 18:46:11.145019 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17343798,
#  'Loss/localization_loss': 0.020951139,
#  'Loss/regularization_loss': 0.092076465,
#  'Loss/total_loss': 0.2864656,
#  'learning_rate': 0.031082997}
# INFO:tensorflow:Step 9300 per-step time 0.553s
# I0622 18:47:06.467302 140614804805504 model_lib_v2.py:699] Step 9300 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.17300749,
#  'Loss/localization_loss': 0.030649656,
#  'Loss/regularization_loss': 0.091702305,
#  'Loss/total_loss': 0.29535946,
#  'learning_rate': 0.030854566}
# I0622 18:47:06.467605 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17300749,
#  'Loss/localization_loss': 0.030649656,
#  'Loss/regularization_loss': 0.091702305,
#  'Loss/total_loss': 0.29535946,
#  'learning_rate': 0.030854566}
# INFO:tensorflow:Step 9400 per-step time 0.553s
# I0622 18:48:01.810046 140614804805504 model_lib_v2.py:699] Step 9400 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.17974336,
#  'Loss/localization_loss': 0.021167746,
#  'Loss/regularization_loss': 0.09110409,
#  'Loss/total_loss': 0.2920152,
#  'learning_rate': 0.030624112}
# I0622 18:48:01.810356 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17974336,
#  'Loss/localization_loss': 0.021167746,
#  'Loss/regularization_loss': 0.09110409,
#  'Loss/total_loss': 0.2920152,
#  'learning_rate': 0.030624112}
# INFO:tensorflow:Step 9500 per-step time 0.553s
# I0622 18:48:57.141945 140614804805504 model_lib_v2.py:699] Step 9500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1660347,
#  'Loss/localization_loss': 0.028849093,
#  'Loss/regularization_loss': 0.090283625,
#  'Loss/total_loss': 0.28516743,
#  'learning_rate': 0.030391678}
# I0622 18:48:57.142243 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1660347,
#  'Loss/localization_loss': 0.028849093,
#  'Loss/regularization_loss': 0.090283625,
#  'Loss/total_loss': 0.28516743,
#  'learning_rate': 0.030391678}
# INFO:tensorflow:Step 9600 per-step time 0.553s
# I0622 18:49:52.490794 140614804805504 model_lib_v2.py:699] Step 9600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.16549855,
#  'Loss/localization_loss': 0.032222953,
#  'Loss/regularization_loss': 0.08948232,
#  'Loss/total_loss': 0.28720382,
#  'learning_rate': 0.030157303}
# I0622 18:49:52.491098 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.16549855,
#  'Loss/localization_loss': 0.032222953,
#  'Loss/regularization_loss': 0.08948232,
#  'Loss/total_loss': 0.28720382,
#  'learning_rate': 0.030157303}
# INFO:tensorflow:Step 9700 per-step time 0.554s
# I0622 18:50:47.841733 140614804805504 model_lib_v2.py:699] Step 9700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.20078175,
#  'Loss/localization_loss': 0.053317904,
#  'Loss/regularization_loss': 0.08895426,
#  'Loss/total_loss': 0.3430539,
#  'learning_rate': 0.029921034}
# I0622 18:50:47.842027 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.20078175,
#  'Loss/localization_loss': 0.053317904,
#  'Loss/regularization_loss': 0.08895426,
#  'Loss/total_loss': 0.3430539,
#  'learning_rate': 0.029921034}
# INFO:tensorflow:Step 9800 per-step time 0.553s
# I0622 18:51:43.149541 140614804805504 model_lib_v2.py:699] Step 9800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.2304629,
#  'Loss/localization_loss': 0.047786035,
#  'Loss/regularization_loss': 0.08830811,
#  'Loss/total_loss': 0.36655703,
#  'learning_rate': 0.029682912}
# I0622 18:51:43.149876 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.2304629,
#  'Loss/localization_loss': 0.047786035,
#  'Loss/regularization_loss': 0.08830811,
#  'Loss/total_loss': 0.36655703,
#  'learning_rate': 0.029682912}
# INFO:tensorflow:Step 9900 per-step time 0.553s
# I0622 18:52:38.446460 140614804805504 model_lib_v2.py:699] Step 9900 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.17816463,
#  'Loss/localization_loss': 0.04522645,
#  'Loss/regularization_loss': 0.087852485,
#  'Loss/total_loss': 0.31124356,
#  'learning_rate': 0.029442988}
# I0622 18:52:38.446766 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17816463,
#  'Loss/localization_loss': 0.04522645,
#  'Loss/regularization_loss': 0.087852485,
#  'Loss/total_loss': 0.31124356,
#  'learning_rate': 0.029442988}
# INFO:tensorflow:Step 10000 per-step time 0.553s
# I0622 18:53:33.785985 140614804805504 model_lib_v2.py:699] Step 10000 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.18890902,
#  'Loss/localization_loss': 0.029755143,
#  'Loss/regularization_loss': 0.08743483,
#  'Loss/total_loss': 0.306099,
#  'learning_rate': 0.029201299}
# I0622 18:53:33.786326 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.18890902,
#  'Loss/localization_loss': 0.029755143,
#  'Loss/regularization_loss': 0.08743483,
#  'Loss/total_loss': 0.306099,
#  'learning_rate': 0.029201299}
# INFO:tensorflow:Step 10100 per-step time 0.572s
# I0622 18:54:31.011664 140614804805504 model_lib_v2.py:699] Step 10100 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.17303187,
#  'Loss/localization_loss': 0.042972554,
#  'Loss/regularization_loss': 0.08674108,
#  'Loss/total_loss': 0.30274552,
#  'learning_rate': 0.028957896}
# I0622 18:54:31.011970 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17303187,
#  'Loss/localization_loss': 0.042972554,
#  'Loss/regularization_loss': 0.08674108,
#  'Loss/total_loss': 0.30274552,
#  'learning_rate': 0.028957896}
# INFO:tensorflow:Step 10200 per-step time 0.553s
# I0622 18:55:26.354552 140614804805504 model_lib_v2.py:699] Step 10200 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.14633025,
#  'Loss/localization_loss': 0.059564594,
#  'Loss/regularization_loss': 0.086222954,
#  'Loss/total_loss': 0.2921178,
#  'learning_rate': 0.028712818}
# I0622 18:55:26.354851 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14633025,
#  'Loss/localization_loss': 0.059564594,
#  'Loss/regularization_loss': 0.086222954,
#  'Loss/total_loss': 0.2921178,
#  'learning_rate': 0.028712818}
# INFO:tensorflow:Step 10300 per-step time 0.553s
# I0622 18:56:21.699866 140614804805504 model_lib_v2.py:699] Step 10300 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1711098,
#  'Loss/localization_loss': 0.0360203,
#  'Loss/regularization_loss': 0.085619405,
#  'Loss/total_loss': 0.2927495,
#  'learning_rate': 0.028466115}
# I0622 18:56:21.700168 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1711098,
#  'Loss/localization_loss': 0.0360203,
#  'Loss/regularization_loss': 0.085619405,
#  'Loss/total_loss': 0.2927495,
#  'learning_rate': 0.028466115}
# INFO:tensorflow:Step 10400 per-step time 0.553s
# I0622 18:57:17.033740 140614804805504 model_lib_v2.py:699] Step 10400 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.15476987,
#  'Loss/localization_loss': 0.033304747,
#  'Loss/regularization_loss': 0.08505444,
#  'Loss/total_loss': 0.27312905,
#  'learning_rate': 0.028217835}
# I0622 18:57:17.034034 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15476987,
#  'Loss/localization_loss': 0.033304747,
#  'Loss/regularization_loss': 0.08505444,
#  'Loss/total_loss': 0.27312905,
#  'learning_rate': 0.028217835}
# INFO:tensorflow:Step 10500 per-step time 0.554s
# I0622 18:58:12.401817 140614804805504 model_lib_v2.py:699] Step 10500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.1980222,
#  'Loss/localization_loss': 0.04605197,
#  'Loss/regularization_loss': 0.08461218,
#  'Loss/total_loss': 0.32868636,
#  'learning_rate': 0.027968023}
# I0622 18:58:12.402117 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1980222,
#  'Loss/localization_loss': 0.04605197,
#  'Loss/regularization_loss': 0.08461218,
#  'Loss/total_loss': 0.32868636,
#  'learning_rate': 0.027968023}
# INFO:tensorflow:Step 10600 per-step time 0.553s
# I0622 18:59:07.726808 140614804805504 model_lib_v2.py:699] Step 10600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1730779,
#  'Loss/localization_loss': 0.022416968,
#  'Loss/regularization_loss': 0.084367566,
#  'Loss/total_loss': 0.27986243,
#  'learning_rate': 0.027716719}
# I0622 18:59:07.727140 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1730779,
#  'Loss/localization_loss': 0.022416968,
#  'Loss/regularization_loss': 0.084367566,
#  'Loss/total_loss': 0.27986243,
#  'learning_rate': 0.027716719}
# INFO:tensorflow:Step 10700 per-step time 0.554s
# I0622 19:00:03.100818 140614804805504 model_lib_v2.py:699] Step 10700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.20005585,
#  'Loss/localization_loss': 0.035247363,
#  'Loss/regularization_loss': 0.08372802,
#  'Loss/total_loss': 0.31903124,
#  'learning_rate': 0.02746398}
# I0622 19:00:03.101122 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.20005585,
#  'Loss/localization_loss': 0.035247363,
#  'Loss/regularization_loss': 0.08372802,
#  'Loss/total_loss': 0.31903124,
#  'learning_rate': 0.02746398}
# INFO:tensorflow:Step 10800 per-step time 0.553s
# I0622 19:00:58.441678 140614804805504 model_lib_v2.py:699] Step 10800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1845302,
#  'Loss/localization_loss': 0.02962829,
#  'Loss/regularization_loss': 0.08301533,
#  'Loss/total_loss': 0.2971738,
#  'learning_rate': 0.027209844}
# I0622 19:00:58.441982 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1845302,
#  'Loss/localization_loss': 0.02962829,
#  'Loss/regularization_loss': 0.08301533,
#  'Loss/total_loss': 0.2971738,
#  'learning_rate': 0.027209844}
# INFO:tensorflow:Step 10900 per-step time 0.554s
# I0622 19:01:53.803396 140614804805504 model_lib_v2.py:699] Step 10900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.13470867,
#  'Loss/localization_loss': 0.025600107,
#  'Loss/regularization_loss': 0.08263308,
#  'Loss/total_loss': 0.24294186,
#  'learning_rate': 0.026954366}
# I0622 19:01:53.803711 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13470867,
#  'Loss/localization_loss': 0.025600107,
#  'Loss/regularization_loss': 0.08263308,
#  'Loss/total_loss': 0.24294186,
#  'learning_rate': 0.026954366}
# INFO:tensorflow:Step 11000 per-step time 0.554s
# I0622 19:02:49.158574 140614804805504 model_lib_v2.py:699] Step 11000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15235189,
#  'Loss/localization_loss': 0.027268449,
#  'Loss/regularization_loss': 0.082249805,
#  'Loss/total_loss': 0.26187015,
#  'learning_rate': 0.026697593}
# I0622 19:02:49.158873 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15235189,
#  'Loss/localization_loss': 0.027268449,
#  'Loss/regularization_loss': 0.082249805,
#  'Loss/total_loss': 0.26187015,
#  'learning_rate': 0.026697593}
# INFO:tensorflow:Step 11100 per-step time 0.567s
# I0622 19:03:45.859877 140614804805504 model_lib_v2.py:699] Step 11100 per-step time 0.567s
# INFO:tensorflow:{'Loss/classification_loss': 0.1897701,
#  'Loss/localization_loss': 0.039575297,
#  'Loss/regularization_loss': 0.08190542,
#  'Loss/total_loss': 0.31125084,
#  'learning_rate': 0.026439566}
# I0622 19:03:45.860196 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1897701,
#  'Loss/localization_loss': 0.039575297,
#  'Loss/regularization_loss': 0.08190542,
#  'Loss/total_loss': 0.31125084,
#  'learning_rate': 0.026439566}
# INFO:tensorflow:Step 11200 per-step time 0.554s
# I0622 19:04:41.261089 140614804805504 model_lib_v2.py:699] Step 11200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.19759901,
#  'Loss/localization_loss': 0.05827158,
#  'Loss/regularization_loss': 0.08141395,
#  'Loss/total_loss': 0.33728454,
#  'learning_rate': 0.026180338}
# I0622 19:04:41.261385 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.19759901,
#  'Loss/localization_loss': 0.05827158,
#  'Loss/regularization_loss': 0.08141395,
#  'Loss/total_loss': 0.33728454,
#  'learning_rate': 0.026180338}
# INFO:tensorflow:Step 11300 per-step time 0.553s
# I0622 19:05:36.596377 140614804805504 model_lib_v2.py:699] Step 11300 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.17926407,
#  'Loss/localization_loss': 0.030966254,
#  'Loss/regularization_loss': 0.080897175,
#  'Loss/total_loss': 0.2911275,
#  'learning_rate': 0.025919959}
# I0622 19:05:36.596704 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17926407,
#  'Loss/localization_loss': 0.030966254,
#  'Loss/regularization_loss': 0.080897175,
#  'Loss/total_loss': 0.2911275,
#  'learning_rate': 0.025919959}
# INFO:tensorflow:Step 11400 per-step time 0.554s
# I0622 19:06:32.015127 140614804805504 model_lib_v2.py:699] Step 11400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15760243,
#  'Loss/localization_loss': 0.038140975,
#  'Loss/regularization_loss': 0.080848075,
#  'Loss/total_loss': 0.27659148,
#  'learning_rate': 0.025658473}
# I0622 19:06:32.015428 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15760243,
#  'Loss/localization_loss': 0.038140975,
#  'Loss/regularization_loss': 0.080848075,
#  'Loss/total_loss': 0.27659148,
#  'learning_rate': 0.025658473}
# INFO:tensorflow:Step 11500 per-step time 0.553s
# I0622 19:07:27.362153 140614804805504 model_lib_v2.py:699] Step 11500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.22040616,
#  'Loss/localization_loss': 0.050493147,
#  'Loss/regularization_loss': 0.080416,
#  'Loss/total_loss': 0.35131532,
#  'learning_rate': 0.025395937}
# I0622 19:07:27.362448 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.22040616,
#  'Loss/localization_loss': 0.050493147,
#  'Loss/regularization_loss': 0.080416,
#  'Loss/total_loss': 0.35131532,
#  'learning_rate': 0.025395937}
# INFO:tensorflow:Step 11600 per-step time 0.553s
# I0622 19:08:22.696283 140614804805504 model_lib_v2.py:699] Step 11600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1987809,
#  'Loss/localization_loss': 0.02666794,
#  'Loss/regularization_loss': 0.08007551,
#  'Loss/total_loss': 0.30552435,
#  'learning_rate': 0.025132386}
# I0622 19:08:22.696607 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1987809,
#  'Loss/localization_loss': 0.02666794,
#  'Loss/regularization_loss': 0.08007551,
#  'Loss/total_loss': 0.30552435,
#  'learning_rate': 0.025132386}
# INFO:tensorflow:Step 11700 per-step time 0.554s
# I0622 19:09:18.075409 140614804805504 model_lib_v2.py:699] Step 11700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.1346672,
#  'Loss/localization_loss': 0.03551353,
#  'Loss/regularization_loss': 0.07981385,
#  'Loss/total_loss': 0.24999459,
#  'learning_rate': 0.024867883}
# I0622 19:09:18.075724 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1346672,
#  'Loss/localization_loss': 0.03551353,
#  'Loss/regularization_loss': 0.07981385,
#  'Loss/total_loss': 0.24999459,
#  'learning_rate': 0.024867883}
# INFO:tensorflow:Step 11800 per-step time 0.553s
# I0622 19:10:13.419275 140614804805504 model_lib_v2.py:699] Step 11800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.17513205,
#  'Loss/localization_loss': 0.034042053,
#  'Loss/regularization_loss': 0.07947894,
#  'Loss/total_loss': 0.28865305,
#  'learning_rate': 0.024602469}
# I0622 19:10:13.419599 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17513205,
#  'Loss/localization_loss': 0.034042053,
#  'Loss/regularization_loss': 0.07947894,
#  'Loss/total_loss': 0.28865305,
#  'learning_rate': 0.024602469}
# INFO:tensorflow:Step 11900 per-step time 0.554s
# I0622 19:11:08.793458 140614804805504 model_lib_v2.py:699] Step 11900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12771538,
#  'Loss/localization_loss': 0.025992816,
#  'Loss/regularization_loss': 0.079060815,
#  'Loss/total_loss': 0.23276901,
#  'learning_rate': 0.024336198}
# I0622 19:11:08.793771 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12771538,
#  'Loss/localization_loss': 0.025992816,
#  'Loss/regularization_loss': 0.079060815,
#  'Loss/total_loss': 0.23276901,
#  'learning_rate': 0.024336198}
# INFO:tensorflow:Step 12000 per-step time 0.554s
# I0622 19:12:04.154678 140614804805504 model_lib_v2.py:699] Step 12000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15692063,
#  'Loss/localization_loss': 0.041025322,
#  'Loss/regularization_loss': 0.07852223,
#  'Loss/total_loss': 0.27646816,
#  'learning_rate': 0.024069117}
# I0622 19:12:04.154982 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15692063,
#  'Loss/localization_loss': 0.041025322,
#  'Loss/regularization_loss': 0.07852223,
#  'Loss/total_loss': 0.27646816,
#  'learning_rate': 0.024069117}
# INFO:tensorflow:Step 12100 per-step time 0.571s
# I0622 19:13:01.273714 140614804805504 model_lib_v2.py:699] Step 12100 per-step time 0.571s
# INFO:tensorflow:{'Loss/classification_loss': 0.1679987,
#  'Loss/localization_loss': 0.032095835,
#  'Loss/regularization_loss': 0.07813237,
#  'Loss/total_loss': 0.2782269,
#  'learning_rate': 0.02380128}
# I0622 19:13:01.274019 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1679987,
#  'Loss/localization_loss': 0.032095835,
#  'Loss/regularization_loss': 0.07813237,
#  'Loss/total_loss': 0.2782269,
#  'learning_rate': 0.02380128}
# INFO:tensorflow:Step 12200 per-step time 0.554s
# I0622 19:13:56.701817 140614804805504 model_lib_v2.py:699] Step 12200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.18835759,
#  'Loss/localization_loss': 0.054740764,
#  'Loss/regularization_loss': 0.07768006,
#  'Loss/total_loss': 0.3207784,
#  'learning_rate': 0.023532731}
# I0622 19:13:56.702159 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.18835759,
#  'Loss/localization_loss': 0.054740764,
#  'Loss/regularization_loss': 0.07768006,
#  'Loss/total_loss': 0.3207784,
#  'learning_rate': 0.023532731}
# INFO:tensorflow:Step 12300 per-step time 0.554s
# I0622 19:14:52.059663 140614804805504 model_lib_v2.py:699] Step 12300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.20300986,
#  'Loss/localization_loss': 0.03789023,
#  'Loss/regularization_loss': 0.077404164,
#  'Loss/total_loss': 0.31830424,
#  'learning_rate': 0.023263523}
# I0622 19:14:52.059959 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.20300986,
#  'Loss/localization_loss': 0.03789023,
#  'Loss/regularization_loss': 0.077404164,
#  'Loss/total_loss': 0.31830424,
#  'learning_rate': 0.023263523}
# INFO:tensorflow:Step 12400 per-step time 0.554s
# I0622 19:15:47.416705 140614804805504 model_lib_v2.py:699] Step 12400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.17052819,
#  'Loss/localization_loss': 0.052543264,
#  'Loss/regularization_loss': 0.07723229,
#  'Loss/total_loss': 0.30030373,
#  'learning_rate': 0.022993708}
# I0622 19:15:47.417011 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17052819,
#  'Loss/localization_loss': 0.052543264,
#  'Loss/regularization_loss': 0.07723229,
#  'Loss/total_loss': 0.30030373,
#  'learning_rate': 0.022993708}
# INFO:tensorflow:Step 12500 per-step time 0.553s
# I0622 19:16:42.717024 140614804805504 model_lib_v2.py:699] Step 12500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1690318,
#  'Loss/localization_loss': 0.030377854,
#  'Loss/regularization_loss': 0.07685019,
#  'Loss/total_loss': 0.27625984,
#  'learning_rate': 0.022723334}
# I0622 19:16:42.717332 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1690318,
#  'Loss/localization_loss': 0.030377854,
#  'Loss/regularization_loss': 0.07685019,
#  'Loss/total_loss': 0.27625984,
#  'learning_rate': 0.022723334}
# INFO:tensorflow:Step 12600 per-step time 0.554s
# I0622 19:17:38.090363 140614804805504 model_lib_v2.py:699] Step 12600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.127883,
#  'Loss/localization_loss': 0.047957048,
#  'Loss/regularization_loss': 0.076371126,
#  'Loss/total_loss': 0.25221115,
#  'learning_rate': 0.02245245}
# I0622 19:17:38.090683 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.127883,
#  'Loss/localization_loss': 0.047957048,
#  'Loss/regularization_loss': 0.076371126,
#  'Loss/total_loss': 0.25221115,
#  'learning_rate': 0.02245245}
# INFO:tensorflow:Step 12700 per-step time 0.554s
# I0622 19:18:33.458101 140614804805504 model_lib_v2.py:699] Step 12700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.143604,
#  'Loss/localization_loss': 0.032993633,
#  'Loss/regularization_loss': 0.07592636,
#  'Loss/total_loss': 0.252524,
#  'learning_rate': 0.022181105}
# I0622 19:18:33.458401 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.143604,
#  'Loss/localization_loss': 0.032993633,
#  'Loss/regularization_loss': 0.07592636,
#  'Loss/total_loss': 0.252524,
#  'learning_rate': 0.022181105}
# INFO:tensorflow:Step 12800 per-step time 0.554s
# I0622 19:19:28.830004 140614804805504 model_lib_v2.py:699] Step 12800 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.14983208,
#  'Loss/localization_loss': 0.031230172,
#  'Loss/regularization_loss': 0.075551555,
#  'Loss/total_loss': 0.25661382,
#  'learning_rate': 0.021909358}
# I0622 19:19:28.830311 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14983208,
#  'Loss/localization_loss': 0.031230172,
#  'Loss/regularization_loss': 0.075551555,
#  'Loss/total_loss': 0.25661382,
#  'learning_rate': 0.021909358}
# INFO:tensorflow:Step 12900 per-step time 0.554s
# I0622 19:20:24.233820 140614804805504 model_lib_v2.py:699] Step 12900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.13878071,
#  'Loss/localization_loss': 0.029088834,
#  'Loss/regularization_loss': 0.075191334,
#  'Loss/total_loss': 0.24306089,
#  'learning_rate': 0.021637257}
# I0622 19:20:24.234128 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13878071,
#  'Loss/localization_loss': 0.029088834,
#  'Loss/regularization_loss': 0.075191334,
#  'Loss/total_loss': 0.24306089,
#  'learning_rate': 0.021637257}
# INFO:tensorflow:Step 13000 per-step time 0.553s
# I0622 19:21:19.570053 140614804805504 model_lib_v2.py:699] Step 13000 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.20693505,
#  'Loss/localization_loss': 0.05602299,
#  'Loss/regularization_loss': 0.07498477,
#  'Loss/total_loss': 0.3379428,
#  'learning_rate': 0.021364845}
# I0622 19:21:19.570358 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.20693505,
#  'Loss/localization_loss': 0.05602299,
#  'Loss/regularization_loss': 0.07498477,
#  'Loss/total_loss': 0.3379428,
#  'learning_rate': 0.021364845}
# INFO:tensorflow:Step 13100 per-step time 0.573s
# I0622 19:22:16.839856 140614804805504 model_lib_v2.py:699] Step 13100 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.16545863,
#  'Loss/localization_loss': 0.021950286,
#  'Loss/regularization_loss': 0.07460666,
#  'Loss/total_loss': 0.26201558,
#  'learning_rate': 0.021092184}
# I0622 19:22:16.840209 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.16545863,
#  'Loss/localization_loss': 0.021950286,
#  'Loss/regularization_loss': 0.07460666,
#  'Loss/total_loss': 0.26201558,
#  'learning_rate': 0.021092184}
# INFO:tensorflow:Step 13200 per-step time 0.554s
# I0622 19:23:12.202355 140614804805504 model_lib_v2.py:699] Step 13200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15587878,
#  'Loss/localization_loss': 0.048402358,
#  'Loss/regularization_loss': 0.07421838,
#  'Loss/total_loss': 0.2784995,
#  'learning_rate': 0.020819314}
# I0622 19:23:12.202674 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15587878,
#  'Loss/localization_loss': 0.048402358,
#  'Loss/regularization_loss': 0.07421838,
#  'Loss/total_loss': 0.2784995,
#  'learning_rate': 0.020819314}
# INFO:tensorflow:Step 13300 per-step time 0.554s
# I0622 19:24:07.588560 140614804805504 model_lib_v2.py:699] Step 13300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.19181155,
#  'Loss/localization_loss': 0.030064227,
#  'Loss/regularization_loss': 0.073849574,
#  'Loss/total_loss': 0.29572535,
#  'learning_rate': 0.020546295}
# I0622 19:24:07.588865 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.19181155,
#  'Loss/localization_loss': 0.030064227,
#  'Loss/regularization_loss': 0.073849574,
#  'Loss/total_loss': 0.29572535,
#  'learning_rate': 0.020546295}
# INFO:tensorflow:Step 13400 per-step time 0.554s
# I0622 19:25:02.964704 140614804805504 model_lib_v2.py:699] Step 13400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12633152,
#  'Loss/localization_loss': 0.027751785,
#  'Loss/regularization_loss': 0.073582046,
#  'Loss/total_loss': 0.22766535,
#  'learning_rate': 0.020273173}
# I0622 19:25:02.964997 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12633152,
#  'Loss/localization_loss': 0.027751785,
#  'Loss/regularization_loss': 0.073582046,
#  'Loss/total_loss': 0.22766535,
#  'learning_rate': 0.020273173}
# INFO:tensorflow:Step 13500 per-step time 0.553s
# I0622 19:25:58.292736 140614804805504 model_lib_v2.py:699] Step 13500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1251231,
#  'Loss/localization_loss': 0.01435008,
#  'Loss/regularization_loss': 0.07341352,
#  'Loss/total_loss': 0.2128867,
#  'learning_rate': 0.019999998}
# I0622 19:25:58.293052 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1251231,
#  'Loss/localization_loss': 0.01435008,
#  'Loss/regularization_loss': 0.07341352,
#  'Loss/total_loss': 0.2128867,
#  'learning_rate': 0.019999998}
# INFO:tensorflow:Step 13600 per-step time 0.553s
# I0622 19:26:53.633668 140614804805504 model_lib_v2.py:699] Step 13600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.14160883,
#  'Loss/localization_loss': 0.043082453,
#  'Loss/regularization_loss': 0.07323071,
#  'Loss/total_loss': 0.257922,
#  'learning_rate': 0.019726824}
# I0622 19:26:53.633961 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14160883,
#  'Loss/localization_loss': 0.043082453,
#  'Loss/regularization_loss': 0.07323071,
#  'Loss/total_loss': 0.257922,
#  'learning_rate': 0.019726824}
# INFO:tensorflow:Step 13700 per-step time 0.554s
# I0622 19:27:48.991391 140614804805504 model_lib_v2.py:699] Step 13700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.11728228,
#  'Loss/localization_loss': 0.01895404,
#  'Loss/regularization_loss': 0.07288932,
#  'Loss/total_loss': 0.20912564,
#  'learning_rate': 0.0194537}
# I0622 19:27:48.991708 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.11728228,
#  'Loss/localization_loss': 0.01895404,
#  'Loss/regularization_loss': 0.07288932,
#  'Loss/total_loss': 0.20912564,
#  'learning_rate': 0.0194537}
# INFO:tensorflow:Step 13800 per-step time 0.554s
# I0622 19:28:44.361104 140614804805504 model_lib_v2.py:699] Step 13800 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.18874283,
#  'Loss/localization_loss': 0.042635407,
#  'Loss/regularization_loss': 0.072538026,
#  'Loss/total_loss': 0.30391628,
#  'learning_rate': 0.019180683}
# I0622 19:28:44.361406 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.18874283,
#  'Loss/localization_loss': 0.042635407,
#  'Loss/regularization_loss': 0.072538026,
#  'Loss/total_loss': 0.30391628,
#  'learning_rate': 0.019180683}
# INFO:tensorflow:Step 13900 per-step time 0.553s
# I0622 19:29:39.700685 140614804805504 model_lib_v2.py:699] Step 13900 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.121861525,
#  'Loss/localization_loss': 0.03018539,
#  'Loss/regularization_loss': 0.07224926,
#  'Loss/total_loss': 0.22429617,
#  'learning_rate': 0.018907815}
# I0622 19:29:39.700981 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.121861525,
#  'Loss/localization_loss': 0.03018539,
#  'Loss/regularization_loss': 0.07224926,
#  'Loss/total_loss': 0.22429617,
#  'learning_rate': 0.018907815}
# INFO:tensorflow:Step 14000 per-step time 0.554s
# I0622 19:30:35.067807 140614804805504 model_lib_v2.py:699] Step 14000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.14978129,
#  'Loss/localization_loss': 0.040330466,
#  'Loss/regularization_loss': 0.07195975,
#  'Loss/total_loss': 0.2620715,
#  'learning_rate': 0.01863515}
# I0622 19:30:35.068115 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14978129,
#  'Loss/localization_loss': 0.040330466,
#  'Loss/regularization_loss': 0.07195975,
#  'Loss/total_loss': 0.2620715,
#  'learning_rate': 0.01863515}
# INFO:tensorflow:Step 14100 per-step time 0.572s
# I0622 19:31:32.260437 140614804805504 model_lib_v2.py:699] Step 14100 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.11979268,
#  'Loss/localization_loss': 0.014869179,
#  'Loss/regularization_loss': 0.071685016,
#  'Loss/total_loss': 0.20634687,
#  'learning_rate': 0.018362742}
# I0622 19:31:32.260822 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.11979268,
#  'Loss/localization_loss': 0.014869179,
#  'Loss/regularization_loss': 0.071685016,
#  'Loss/total_loss': 0.20634687,
#  'learning_rate': 0.018362742}
# INFO:tensorflow:Step 14200 per-step time 0.554s
# I0622 19:32:27.653714 140614804805504 model_lib_v2.py:699] Step 14200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.14494611,
#  'Loss/localization_loss': 0.030372884,
#  'Loss/regularization_loss': 0.071419254,
#  'Loss/total_loss': 0.24673826,
#  'learning_rate': 0.01809064}
# I0622 19:32:27.654025 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14494611,
#  'Loss/localization_loss': 0.030372884,
#  'Loss/regularization_loss': 0.071419254,
#  'Loss/total_loss': 0.24673826,
#  'learning_rate': 0.01809064}
# INFO:tensorflow:Step 14300 per-step time 0.554s
# I0622 19:33:23.046466 140614804805504 model_lib_v2.py:699] Step 14300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.1653201,
#  'Loss/localization_loss': 0.03612994,
#  'Loss/regularization_loss': 0.07121908,
#  'Loss/total_loss': 0.27266914,
#  'learning_rate': 0.017818892}
# I0622 19:33:23.046787 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1653201,
#  'Loss/localization_loss': 0.03612994,
#  'Loss/regularization_loss': 0.07121908,
#  'Loss/total_loss': 0.27266914,
#  'learning_rate': 0.017818892}
# INFO:tensorflow:Step 14400 per-step time 0.554s
# I0622 19:34:18.419318 140614804805504 model_lib_v2.py:699] Step 14400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15504847,
#  'Loss/localization_loss': 0.03703637,
#  'Loss/regularization_loss': 0.07083466,
#  'Loss/total_loss': 0.2629195,
#  'learning_rate': 0.01754755}
# I0622 19:34:18.419684 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15504847,
#  'Loss/localization_loss': 0.03703637,
#  'Loss/regularization_loss': 0.07083466,
#  'Loss/total_loss': 0.2629195,
#  'learning_rate': 0.01754755}
# INFO:tensorflow:Step 14500 per-step time 0.554s
# I0622 19:35:13.831824 140614804805504 model_lib_v2.py:699] Step 14500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.1435993,
#  'Loss/localization_loss': 0.030227188,
#  'Loss/regularization_loss': 0.070512556,
#  'Loss/total_loss': 0.24433905,
#  'learning_rate': 0.017276663}
# I0622 19:35:13.832124 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1435993,
#  'Loss/localization_loss': 0.030227188,
#  'Loss/regularization_loss': 0.070512556,
#  'Loss/total_loss': 0.24433905,
#  'learning_rate': 0.017276663}
# INFO:tensorflow:Step 14600 per-step time 0.554s
# I0622 19:36:09.185511 140614804805504 model_lib_v2.py:699] Step 14600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.13277853,
#  'Loss/localization_loss': 0.023934176,
#  'Loss/regularization_loss': 0.07027878,
#  'Loss/total_loss': 0.22699147,
#  'learning_rate': 0.01700629}
# I0622 19:36:09.185831 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13277853,
#  'Loss/localization_loss': 0.023934176,
#  'Loss/regularization_loss': 0.07027878,
#  'Loss/total_loss': 0.22699147,
#  'learning_rate': 0.01700629}
# INFO:tensorflow:Step 14700 per-step time 0.553s
# I0622 19:37:04.521660 140614804805504 model_lib_v2.py:699] Step 14700 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.18905745,
#  'Loss/localization_loss': 0.028102508,
#  'Loss/regularization_loss': 0.06997022,
#  'Loss/total_loss': 0.28713018,
#  'learning_rate': 0.016736476}
# I0622 19:37:04.521958 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.18905745,
#  'Loss/localization_loss': 0.028102508,
#  'Loss/regularization_loss': 0.06997022,
#  'Loss/total_loss': 0.28713018,
#  'learning_rate': 0.016736476}
# INFO:tensorflow:Step 14800 per-step time 0.554s
# I0622 19:37:59.917080 140614804805504 model_lib_v2.py:699] Step 14800 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15872994,
#  'Loss/localization_loss': 0.017088376,
#  'Loss/regularization_loss': 0.06971201,
#  'Loss/total_loss': 0.24553034,
#  'learning_rate': 0.016467266}
# I0622 19:37:59.917393 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15872994,
#  'Loss/localization_loss': 0.017088376,
#  'Loss/regularization_loss': 0.06971201,
#  'Loss/total_loss': 0.24553034,
#  'learning_rate': 0.016467266}
# INFO:tensorflow:Step 14900 per-step time 0.554s
# I0622 19:38:55.266552 140614804805504 model_lib_v2.py:699] Step 14900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.18354447,
#  'Loss/localization_loss': 0.034864634,
#  'Loss/regularization_loss': 0.06956629,
#  'Loss/total_loss': 0.2879754,
#  'learning_rate': 0.016198717}
# I0622 19:38:55.266854 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.18354447,
#  'Loss/localization_loss': 0.034864634,
#  'Loss/regularization_loss': 0.06956629,
#  'Loss/total_loss': 0.2879754,
#  'learning_rate': 0.016198717}
# INFO:tensorflow:Step 15000 per-step time 0.553s
# I0622 19:39:50.614026 140614804805504 model_lib_v2.py:699] Step 15000 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.13148251,
#  'Loss/localization_loss': 0.018729014,
#  'Loss/regularization_loss': 0.06918214,
#  'Loss/total_loss': 0.21939367,
#  'learning_rate': 0.015930876}
# I0622 19:39:50.614329 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13148251,
#  'Loss/localization_loss': 0.018729014,
#  'Loss/regularization_loss': 0.06918214,
#  'Loss/total_loss': 0.21939367,
#  'learning_rate': 0.015930876}
# INFO:tensorflow:Step 15100 per-step time 0.568s
# I0622 19:40:47.412719 140614804805504 model_lib_v2.py:699] Step 15100 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.14964248,
#  'Loss/localization_loss': 0.028734086,
#  'Loss/regularization_loss': 0.06890404,
#  'Loss/total_loss': 0.24728061,
#  'learning_rate': 0.015663799}
# I0622 19:40:47.413071 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.14964248,
#  'Loss/localization_loss': 0.028734086,
#  'Loss/regularization_loss': 0.06890404,
#  'Loss/total_loss': 0.24728061,
#  'learning_rate': 0.015663799}
# INFO:tensorflow:Step 15200 per-step time 0.554s
# I0622 19:41:42.800044 140614804805504 model_lib_v2.py:699] Step 15200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.13060012,
#  'Loss/localization_loss': 0.014002371,
#  'Loss/regularization_loss': 0.068623796,
#  'Loss/total_loss': 0.21322629,
#  'learning_rate': 0.015397527}
# I0622 19:41:42.800354 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13060012,
#  'Loss/localization_loss': 0.014002371,
#  'Loss/regularization_loss': 0.068623796,
#  'Loss/total_loss': 0.21322629,
#  'learning_rate': 0.015397527}
# INFO:tensorflow:Step 15300 per-step time 0.554s
# I0622 19:42:38.182991 140614804805504 model_lib_v2.py:699] Step 15300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15444781,
#  'Loss/localization_loss': 0.022191633,
#  'Loss/regularization_loss': 0.06834173,
#  'Loss/total_loss': 0.24498117,
#  'learning_rate': 0.015132114}
# I0622 19:42:38.183304 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15444781,
#  'Loss/localization_loss': 0.022191633,
#  'Loss/regularization_loss': 0.06834173,
#  'Loss/total_loss': 0.24498117,
#  'learning_rate': 0.015132114}
# INFO:tensorflow:Step 15400 per-step time 0.554s
# I0622 19:43:33.606930 140614804805504 model_lib_v2.py:699] Step 15400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15812135,
#  'Loss/localization_loss': 0.038329136,
#  'Loss/regularization_loss': 0.06812979,
#  'Loss/total_loss': 0.26458028,
#  'learning_rate': 0.014867609}
# I0622 19:43:33.607307 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15812135,
#  'Loss/localization_loss': 0.038329136,
#  'Loss/regularization_loss': 0.06812979,
#  'Loss/total_loss': 0.26458028,
#  'learning_rate': 0.014867609}
# INFO:tensorflow:Step 15500 per-step time 0.554s
# I0622 19:44:29.022840 140614804805504 model_lib_v2.py:699] Step 15500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.16011317,
#  'Loss/localization_loss': 0.035622355,
#  'Loss/regularization_loss': 0.06787116,
#  'Loss/total_loss': 0.2636067,
#  'learning_rate': 0.014604063}
# I0622 19:44:29.023143 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.16011317,
#  'Loss/localization_loss': 0.035622355,
#  'Loss/regularization_loss': 0.06787116,
#  'Loss/total_loss': 0.2636067,
#  'learning_rate': 0.014604063}
# INFO:tensorflow:Step 15600 per-step time 0.553s
# I0622 19:45:24.371711 140614804805504 model_lib_v2.py:699] Step 15600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1388272,
#  'Loss/localization_loss': 0.022208432,
#  'Loss/regularization_loss': 0.0675663,
#  'Loss/total_loss': 0.22860195,
#  'learning_rate': 0.014341523}
# I0622 19:45:24.372012 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1388272,
#  'Loss/localization_loss': 0.022208432,
#  'Loss/regularization_loss': 0.0675663,
#  'Loss/total_loss': 0.22860195,
#  'learning_rate': 0.014341523}
# INFO:tensorflow:Step 15700 per-step time 0.554s
# I0622 19:46:19.729907 140614804805504 model_lib_v2.py:699] Step 15700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12976572,
#  'Loss/localization_loss': 0.04886627,
#  'Loss/regularization_loss': 0.06726588,
#  'Loss/total_loss': 0.24589787,
#  'learning_rate': 0.01408004}
# I0622 19:46:19.730233 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12976572,
#  'Loss/localization_loss': 0.04886627,
#  'Loss/regularization_loss': 0.06726588,
#  'Loss/total_loss': 0.24589787,
#  'learning_rate': 0.01408004}
# INFO:tensorflow:Step 15800 per-step time 0.553s
# I0622 19:47:15.079938 140614804805504 model_lib_v2.py:699] Step 15800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.24002255,
#  'Loss/localization_loss': 0.026840365,
#  'Loss/regularization_loss': 0.066980295,
#  'Loss/total_loss': 0.3338432,
#  'learning_rate': 0.013819658}
# I0622 19:47:15.080244 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.24002255,
#  'Loss/localization_loss': 0.026840365,
#  'Loss/regularization_loss': 0.066980295,
#  'Loss/total_loss': 0.3338432,
#  'learning_rate': 0.013819658}
# INFO:tensorflow:Step 15900 per-step time 0.554s
# I0622 19:48:10.455818 140614804805504 model_lib_v2.py:699] Step 15900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.19380721,
#  'Loss/localization_loss': 0.03355328,
#  'Loss/regularization_loss': 0.06669992,
#  'Loss/total_loss': 0.2940604,
#  'learning_rate': 0.013560432}
# I0622 19:48:10.456123 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.19380721,
#  'Loss/localization_loss': 0.03355328,
#  'Loss/regularization_loss': 0.06669992,
#  'Loss/total_loss': 0.2940604,
#  'learning_rate': 0.013560432}
# INFO:tensorflow:Step 16000 per-step time 0.554s
# I0622 19:49:05.837841 140614804805504 model_lib_v2.py:699] Step 16000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12739022,
#  'Loss/localization_loss': 0.028963542,
#  'Loss/regularization_loss': 0.066525124,
#  'Loss/total_loss': 0.22287887,
#  'learning_rate': 0.013302408}
# I0622 19:49:05.838146 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12739022,
#  'Loss/localization_loss': 0.028963542,
#  'Loss/regularization_loss': 0.066525124,
#  'Loss/total_loss': 0.22287887,
#  'learning_rate': 0.013302408}
# INFO:tensorflow:Step 16100 per-step time 0.569s
# I0622 19:50:02.702941 140614804805504 model_lib_v2.py:699] Step 16100 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.12325705,
#  'Loss/localization_loss': 0.020576535,
#  'Loss/regularization_loss': 0.06629531,
#  'Loss/total_loss': 0.2101289,
#  'learning_rate': 0.013045632}
# I0622 19:50:02.703274 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12325705,
#  'Loss/localization_loss': 0.020576535,
#  'Loss/regularization_loss': 0.06629531,
#  'Loss/total_loss': 0.2101289,
#  'learning_rate': 0.013045632}
# INFO:tensorflow:Step 16200 per-step time 0.554s
# I0622 19:50:58.136680 140614804805504 model_lib_v2.py:699] Step 16200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.17648678,
#  'Loss/localization_loss': 0.044188272,
#  'Loss/regularization_loss': 0.06602072,
#  'Loss/total_loss': 0.28669575,
#  'learning_rate': 0.012790153}
# I0622 19:50:58.136977 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17648678,
#  'Loss/localization_loss': 0.044188272,
#  'Loss/regularization_loss': 0.06602072,
#  'Loss/total_loss': 0.28669575,
#  'learning_rate': 0.012790153}
# INFO:tensorflow:Step 16300 per-step time 0.554s
# I0622 19:51:53.531282 140614804805504 model_lib_v2.py:699] Step 16300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12968007,
#  'Loss/localization_loss': 0.027512213,
#  'Loss/regularization_loss': 0.0657477,
#  'Loss/total_loss': 0.22293998,
#  'learning_rate': 0.012536017}
# I0622 19:51:53.531597 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12968007,
#  'Loss/localization_loss': 0.027512213,
#  'Loss/regularization_loss': 0.0657477,
#  'Loss/total_loss': 0.22293998,
#  'learning_rate': 0.012536017}
# INFO:tensorflow:Step 16400 per-step time 0.554s
# I0622 19:52:48.894648 140614804805504 model_lib_v2.py:699] Step 16400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12944275,
#  'Loss/localization_loss': 0.023056218,
#  'Loss/regularization_loss': 0.06551809,
#  'Loss/total_loss': 0.21801706,
#  'learning_rate': 0.01228328}
# I0622 19:52:48.894966 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.12944275,
#  'Loss/localization_loss': 0.023056218,
#  'Loss/regularization_loss': 0.06551809,
#  'Loss/total_loss': 0.21801706,
#  'learning_rate': 0.01228328}
# INFO:tensorflow:Step 16500 per-step time 0.553s
# I0622 19:53:44.196286 140614804805504 model_lib_v2.py:699] Step 16500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.15523638,
#  'Loss/localization_loss': 0.028718526,
#  'Loss/regularization_loss': 0.06539112,
#  'Loss/total_loss': 0.24934603,
#  'learning_rate': 0.012031979}
# I0622 19:53:44.196600 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15523638,
#  'Loss/localization_loss': 0.028718526,
#  'Loss/regularization_loss': 0.06539112,
#  'Loss/total_loss': 0.24934603,
#  'learning_rate': 0.012031979}
# INFO:tensorflow:Step 16600 per-step time 0.553s
# I0622 19:54:39.546169 140614804805504 model_lib_v2.py:699] Step 16600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.16271178,
#  'Loss/localization_loss': 0.0474479,
#  'Loss/regularization_loss': 0.06517249,
#  'Loss/total_loss': 0.27533218,
#  'learning_rate': 0.011782162}
# I0622 19:54:39.546494 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.16271178,
# ...
#  'Loss/total_loss': 0.15736696,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47300 per-step time 0.554s
# I0623 00:38:43.807116 140614804805504 model_lib_v2.py:699] Step 47300 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.10490116,
#  'Loss/localization_loss': 0.02584692,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18756583,
#  'learning_rate': 0.0}
# I0623 00:38:43.807413 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10490116,
#  'Loss/localization_loss': 0.02584692,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18756583,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47400 per-step time 0.554s
# I0623 00:39:39.181021 140614804805504 model_lib_v2.py:699] Step 47400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.090876214,
#  'Loss/localization_loss': 0.0222936,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16998756,
#  'learning_rate': 0.0}
# I0623 00:39:39.181328 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.090876214,
#  'Loss/localization_loss': 0.0222936,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16998756,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47500 per-step time 0.553s
# I0623 00:40:34.518575 140614804805504 model_lib_v2.py:699] Step 47500 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.10209136,
#  'Loss/localization_loss': 0.021809228,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18071833,
#  'learning_rate': 0.0}
# I0623 00:40:34.518884 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10209136,
#  'Loss/localization_loss': 0.021809228,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18071833,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47600 per-step time 0.554s
# I0623 00:41:29.941936 140614804805504 model_lib_v2.py:699] Step 47600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.17036037,
#  'Loss/localization_loss': 0.023992602,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.25117072,
#  'learning_rate': 0.0}
# I0623 00:41:29.942242 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.17036037,
#  'Loss/localization_loss': 0.023992602,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.25117072,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47700 per-step time 0.554s
# I0623 00:42:25.330208 140614804805504 model_lib_v2.py:699] Step 47700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.09694895,
#  'Loss/localization_loss': 0.031863358,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18563005,
#  'learning_rate': 0.0}
# I0623 00:42:25.330524 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.09694895,
#  'Loss/localization_loss': 0.031863358,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18563005,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47800 per-step time 0.553s
# I0623 00:43:20.667444 140614804805504 model_lib_v2.py:699] Step 47800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.08669337,
#  'Loss/localization_loss': 0.026045809,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16955693,
#  'learning_rate': 0.0}
# I0623 00:43:20.667827 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.08669337,
#  'Loss/localization_loss': 0.026045809,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16955693,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 47900 per-step time 0.554s
# I0623 00:44:16.025192 140614804805504 model_lib_v2.py:699] Step 47900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.090770066,
#  'Loss/localization_loss': 0.025326094,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1729139,
#  'learning_rate': 0.0}
# I0623 00:44:16.025511 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.090770066,
#  'Loss/localization_loss': 0.025326094,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1729139,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48000 per-step time 0.554s
# I0623 00:45:11.445234 140614804805504 model_lib_v2.py:699] Step 48000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.0926416,
#  'Loss/localization_loss': 0.029960178,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17941952,
#  'learning_rate': 0.0}
# I0623 00:45:11.445575 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.0926416,
#  'Loss/localization_loss': 0.029960178,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17941952,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48100 per-step time 0.568s
# I0623 00:46:08.284173 140614804805504 model_lib_v2.py:699] Step 48100 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.08817129,
#  'Loss/localization_loss': 0.021692157,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1666812,
#  'learning_rate': 0.0}
# I0623 00:46:08.284484 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.08817129,
#  'Loss/localization_loss': 0.021692157,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1666812,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48200 per-step time 0.554s
# I0623 00:47:03.681786 140614804805504 model_lib_v2.py:699] Step 48200 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.15938783,
#  'Loss/localization_loss': 0.046355445,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.26256102,
#  'learning_rate': 0.0}
# I0623 00:47:03.682096 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.15938783,
#  'Loss/localization_loss': 0.046355445,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.26256102,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48300 per-step time 0.553s
# I0623 00:47:59.024548 140614804805504 model_lib_v2.py:699] Step 48300 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.13909028,
#  'Loss/localization_loss': 0.02690778,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.22281581,
#  'learning_rate': 0.0}
# I0623 00:47:59.024859 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.13909028,
#  'Loss/localization_loss': 0.02690778,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.22281581,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48400 per-step time 0.554s
# I0623 00:48:54.393816 140614804805504 model_lib_v2.py:699] Step 48400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.11430819,
#  'Loss/localization_loss': 0.028811144,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.19993709,
#  'learning_rate': 0.0}
# I0623 00:48:54.394112 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.11430819,
#  'Loss/localization_loss': 0.028811144,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.19993709,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48500 per-step time 0.554s
# I0623 00:49:49.769776 140614804805504 model_lib_v2.py:699] Step 48500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.104278326,
#  'Loss/localization_loss': 0.019520372,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18061644,
#  'learning_rate': 0.0}
# I0623 00:49:49.770077 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.104278326,
#  'Loss/localization_loss': 0.019520372,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18061644,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48600 per-step time 0.554s
# I0623 00:50:45.123556 140614804805504 model_lib_v2.py:699] Step 48600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.06896752,
#  'Loss/localization_loss': 0.014595067,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.14038032,
#  'learning_rate': 0.0}
# I0623 00:50:45.123855 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.06896752,
#  'Loss/localization_loss': 0.014595067,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.14038032,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48700 per-step time 0.554s
# I0623 00:51:40.486773 140614804805504 model_lib_v2.py:699] Step 48700 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.08886431,
#  'Loss/localization_loss': 0.016349101,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16203117,
#  'learning_rate': 0.0}
# I0623 00:51:40.487076 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.08886431,
#  'Loss/localization_loss': 0.016349101,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16203117,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48800 per-step time 0.554s
# I0623 00:52:35.867963 140614804805504 model_lib_v2.py:699] Step 48800 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.09997224,
#  'Loss/localization_loss': 0.034002345,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.19079234,
#  'learning_rate': 0.0}
# I0623 00:52:35.868276 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.09997224,
#  'Loss/localization_loss': 0.034002345,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.19079234,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 48900 per-step time 0.553s
# I0623 00:53:31.200481 140614804805504 model_lib_v2.py:699] Step 48900 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.11785103,
#  'Loss/localization_loss': 0.025349459,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.20001823,
#  'learning_rate': 0.0}
# I0623 00:53:31.200828 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.11785103,
#  'Loss/localization_loss': 0.025349459,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.20001823,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49000 per-step time 0.554s
# I0623 00:54:26.558096 140614804805504 model_lib_v2.py:699] Step 49000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.10924514,
#  'Loss/localization_loss': 0.042984843,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.20904773,
#  'learning_rate': 0.0}
# I0623 00:54:26.558401 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10924514,
#  'Loss/localization_loss': 0.042984843,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.20904773,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49100 per-step time 0.568s
# I0623 00:55:23.361625 140614804805504 model_lib_v2.py:699] Step 49100 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.08034707,
#  'Loss/localization_loss': 0.028548213,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16571303,
#  'learning_rate': 0.0}
# I0623 00:55:23.361930 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.08034707,
#  'Loss/localization_loss': 0.028548213,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.16571303,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49200 per-step time 0.553s
# I0623 00:56:18.702109 140614804805504 model_lib_v2.py:699] Step 49200 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.0839766,
#  'Loss/localization_loss': 0.014433726,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.15522806,
#  'learning_rate': 0.0}
# I0623 00:56:18.702423 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.0839766,
#  'Loss/localization_loss': 0.014433726,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.15522806,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49300 per-step time 0.553s
# I0623 00:57:14.034566 140614804805504 model_lib_v2.py:699] Step 49300 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.093950346,
#  'Loss/localization_loss': 0.017163612,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1679317,
#  'learning_rate': 0.0}
# I0623 00:57:14.034869 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.093950346,
#  'Loss/localization_loss': 0.017163612,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1679317,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49400 per-step time 0.554s
# I0623 00:58:09.428930 140614804805504 model_lib_v2.py:699] Step 49400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.0930674,
#  'Loss/localization_loss': 0.022610405,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17249556,
#  'learning_rate': 0.0}
# I0623 00:58:09.429232 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.0930674,
#  'Loss/localization_loss': 0.022610405,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17249556,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49500 per-step time 0.554s
# I0623 00:59:04.796160 140614804805504 model_lib_v2.py:699] Step 49500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.10107532,
#  'Loss/localization_loss': 0.01605597,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17394903,
#  'learning_rate': 0.0}
# I0623 00:59:04.796458 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10107532,
#  'Loss/localization_loss': 0.01605597,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17394903,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49600 per-step time 0.554s
# I0623 01:00:00.168636 140614804805504 model_lib_v2.py:699] Step 49600 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.08885635,
#  'Loss/localization_loss': 0.025870448,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17154454,
#  'learning_rate': 0.0}
# I0623 01:00:00.168936 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.08885635,
#  'Loss/localization_loss': 0.025870448,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17154454,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49700 per-step time 0.553s
# I0623 01:00:55.505522 140614804805504 model_lib_v2.py:699] Step 49700 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.073432684,
#  'Loss/localization_loss': 0.016490173,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1467406,
#  'learning_rate': 0.0}
# I0623 01:00:55.505825 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.073432684,
#  'Loss/localization_loss': 0.016490173,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.1467406,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49800 per-step time 0.553s
# I0623 01:01:50.838609 140614804805504 model_lib_v2.py:699] Step 49800 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.1320375,
#  'Loss/localization_loss': 0.032918714,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.22177398,
#  'learning_rate': 0.0}
# I0623 01:01:50.838908 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.1320375,
#  'Loss/localization_loss': 0.032918714,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.22177398,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 49900 per-step time 0.554s
# I0623 01:02:46.228163 140614804805504 model_lib_v2.py:699] Step 49900 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.10228144,
#  'Loss/localization_loss': 0.028058102,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18715729,
#  'learning_rate': 0.0}
# I0623 01:02:46.228464 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10228144,
#  'Loss/localization_loss': 0.028058102,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.18715729,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 50000 per-step time 0.553s
# I0623 01:03:41.546344 140614804805504 model_lib_v2.py:699] Step 50000 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.10156334,
#  'Loss/localization_loss': 0.018674783,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17705587,
#  'learning_rate': 0.0}
# I0623 01:03:41.546685 140614804805504 model_lib_v2.py:700] {'Loss/classification_loss': 0.10156334,
#  'Loss/localization_loss': 0.018674783,
#  'Loss/regularization_loss': 0.056817748,
#  'Loss/total_loss': 0.17705587,
#  'learning_rate': 0.0}

# %%
# !python model_main_tf2.py --model_dir=models/my_ssd_resnet50_fpn_cl_augmented --pipeline_config_path=models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config --checkpoint_dir=models/my_ssd_resnet50_fpn_cl_augmented
# Out:
# 2021-07-31 08:58:45.068529: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0731 08:58:51.331275 140166655448960 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0731 08:58:51.331538 140166655448960 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0731 08:58:51.331628 140166655448960 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0731 08:58:51.331710 140166655448960 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0731 08:58:51.331824 140166655448960 model_lib_v2.py:1102] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2021-07-31 08:58:51.335824: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-31 08:58:51.349824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.350456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-31 08:58:51.350504: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-31 08:58:51.361211: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-31 08:58:51.361309: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-31 08:58:51.362848: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-07-31 08:58:51.363190: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-07-31 08:58:51.365002: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-07-31 08:58:51.371495: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-07-31 08:58:51.371700: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-31 08:58:51.371816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.372447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.372972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-31 08:58:51.373481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.374024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-31 08:58:51.374102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.374670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.375182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-31 08:58:51.375228: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-31 08:58:51.980620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-31 08:58:51.980675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-31 08:58:51.980691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-31 08:58:51.980934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.981869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.982603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 08:58:51.983151: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-07-31 08:58:51.983205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15433 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Reading unweighted datasets: ['annotations/test.record']
# I0731 08:58:52.202750 140166655448960 dataset_builder.py:163] Reading unweighted datasets: ['annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/test.record']
# I0731 08:58:52.203160 140166655448960 dataset_builder.py:80] Reading record datasets for input file: ['annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0731 08:58:52.203312 140166655448960 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0731 08:58:52.203384 140166655448960 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0731 08:58:52.211556 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0731 08:58:52.241072 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0731 08:58:55.847066 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0731 08:58:56.938675 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented
# I0731 08:58:59.455291 140166655448960 checkpoint_utils.py:140] Waiting for new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented
# INFO:tensorflow:Found new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented/ckpt-51
# I0731 08:58:59.764311 140166655448960 checkpoint_utils.py:149] Found new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented/ckpt-51
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2021-07-31 08:59:01.635521: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-31 08:59:01.636206: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2199995000 Hz
# 2021-07-31 08:59:26.066264: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-31 08:59:27.203314: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8004
# 2021-07-31 08:59:37.429356: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-31 08:59:39.791510: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0731 08:59:40.608581 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0731 08:59:40.616753 140166655448960 model_lib_v2.py:957] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0731 08:59:40.747926 140166655448960 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0731 08:59:48.901041 140166655448960 model_lib_v2.py:957] Finished eval step 100
# INFO:tensorflow:Performing evaluation on 109 images.
# I0731 09:00:23.760721 140166655448960 coco_evaluation.py:293] Performing evaluation on 109 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0731 09:00:23.761626 140166655448960 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0731 09:00:23.767644 140166655448960 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.68s).
# Accumulating evaluation results...
# DONE (t=0.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.938
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.927
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.823
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.833
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.906
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.910
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.909
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# INFO:tensorflow:Eval metrics at step 50000
# I0731 09:00:24.567288 140166655448960 model_lib_v2.py:1006] Eval metrics at step 50000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.828481
# I0731 09:00:24.571908 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP: 0.828481
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.937669
# I0731 09:00:24.573162 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.937669
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.927123
# I0731 09:00:24.574301 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.927123
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.823097
# I0731 09:00:24.575460 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (small): 0.823097
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.833102
# I0731 09:00:24.576601 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (medium): 0.833102
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): -1.000000
# I0731 09:00:24.577703 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (large): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.571770
# I0731 09:00:24.578849 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@1: 0.571770
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.905695
# I0731 09:00:24.579990 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@10: 0.905695
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.909686
# I0731 09:00:24.581022 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100: 0.909686
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.910586
# I0731 09:00:24.582079 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (small): 0.910586
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.908655
# I0731 09:00:24.583232 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.908655
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# I0731 09:00:24.584377 140166655448960 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# INFO:tensorflow:	+ Loss/localization_loss: 0.016857
# I0731 09:00:24.585253 140166655448960 model_lib_v2.py:1009] 	+ Loss/localization_loss: 0.016857
# INFO:tensorflow:	+ Loss/classification_loss: 0.136639
# I0731 09:00:24.586109 140166655448960 model_lib_v2.py:1009] 	+ Loss/classification_loss: 0.136639
# INFO:tensorflow:	+ Loss/regularization_loss: 0.056818
# I0731 09:00:24.586971 140166655448960 model_lib_v2.py:1009] 	+ Loss/regularization_loss: 0.056818
# INFO:tensorflow:	+ Loss/total_loss: 0.210314
# I0731 09:00:24.587833 140166655448960 model_lib_v2.py:1009] 	+ Loss/total_loss: 0.210314
# Traceback (most recent call last):
#   File "model_main_tf2.py", line 115, in <module>
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "model_main_tf2.py", line 90, in main
#     wait_interval=300, timeout=FLAGS.eval_timeout)
#   File "/usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py", line 1128, in eval_continuously
#     checkpoint_dir, timeout=timeout, min_interval_secs=wait_interval):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 216, in checkpoints_iterator
#     time.sleep(time_to_next_eval)
# KeyboardInterrupt

# %% [markdown]
# ### INFERENCE

# %%
# !python model_main_tf2.py --model_dir=models/my_ssd_resnet50_fpn_cl_augmented --pipeline_config_path=models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config --checkpoint_dir=models/my_ssd_resnet50_fpn_cl_augmented
# Out:
# 2021-06-22 01:02:50.782799: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0622 01:02:52.858551 140233411491712 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0622 01:02:52.858774 140233411491712 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0622 01:02:52.858868 140233411491712 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0622 01:02:52.858952 140233411491712 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0622 01:02:52.859080 140233411491712 model_lib_v2.py:1102] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2021-06-22 01:02:52.862756: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-22 01:02:52.879379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.879968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-06-22 01:02:52.880007: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-22 01:02:52.882629: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-06-22 01:02:52.882712: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-06-22 01:02:52.884379: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-06-22 01:02:52.884762: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-06-22 01:02:52.886826: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-06-22 01:02:52.887487: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-06-22 01:02:52.887676: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-06-22 01:02:52.887780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.888448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.889004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-22 01:02:52.889560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.890158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-06-22 01:02:52.890239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.890792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:52.891324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-22 01:02:52.891376: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-22 01:02:53.493349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-22 01:02:53.493397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-06-22 01:02:53.493417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-06-22 01:02:53.493612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:53.494297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:53.494950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-22 01:02:53.495534: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-06-22 01:02:53.495622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15433 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Reading unweighted datasets: ['annotations/test.record']
# I0622 01:02:53.522998 140233411491712 dataset_builder.py:163] Reading unweighted datasets: ['annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/test.record']
# I0622 01:02:53.523370 140233411491712 dataset_builder.py:80] Reading record datasets for input file: ['annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0622 01:02:53.523513 140233411491712 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0622 01:02:53.523592 140233411491712 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0622 01:02:53.525120 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0622 01:02:53.542461 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0622 01:02:57.124454 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0622 01:02:58.203701 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented
# I0622 01:03:00.731884 140233411491712 checkpoint_utils.py:140] Waiting for new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented
# INFO:tensorflow:Found new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented/ckpt-51
# I0622 01:03:00.734508 140233411491712 checkpoint_utils.py:149] Found new checkpoint at models/my_ssd_resnet50_fpn_cl_augmented/ckpt-51
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2021-06-22 01:03:00.813697: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-06-22 01:03:00.814191: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2299995000 Hz
# 2021-06-22 01:03:22.565763: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-06-22 01:03:22.854473: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8004
# 2021-06-22 01:03:23.025762: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-06-22 01:03:23.490295: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0622 01:03:23.956754 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0622 01:03:23.964150 140233411491712 model_lib_v2.py:957] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0622 01:03:24.089249 140233411491712 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0622 01:03:31.842256 140233411491712 model_lib_v2.py:957] Finished eval step 100
# INFO:tensorflow:Performing evaluation on 109 images.
# I0622 01:03:41.898272 140233411491712 coco_evaluation.py:293] Performing evaluation on 109 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0622 01:03:41.898933 140233411491712 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0622 01:03:41.904428 140233411491712 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.64s).
# Accumulating evaluation results...
# DONE (t=0.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.906
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# INFO:tensorflow:Eval metrics at step 50000
# I0622 01:03:42.656615 140233411491712 model_lib_v2.py:1006] Eval metrics at step 50000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.905242
# I0622 01:03:42.660919 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP: 0.905242
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.994969
# I0622 01:03:42.662214 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.994969
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.994089
# I0622 01:03:42.663474 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.994089
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.907899
# I0622 01:03:42.664712 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (small): 0.907899
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.906012
# I0622 01:03:42.665946 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (medium): 0.906012
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): -1.000000
# I0622 01:03:42.667132 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Precision/mAP (large): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.603863
# I0622 01:03:42.668307 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@1: 0.603863
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.932581
# I0622 01:03:42.669471 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@10: 0.932581
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.932581
# I0622 01:03:42.670451 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100: 0.932581
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.932532
# I0622 01:03:42.671565 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (small): 0.932532
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.932895
# I0622 01:03:42.672657 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.932895
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# I0622 01:03:42.673777 140233411491712 model_lib_v2.py:1009] 	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# INFO:tensorflow:	+ Loss/localization_loss: 0.011663
# I0622 01:03:42.674681 140233411491712 model_lib_v2.py:1009] 	+ Loss/localization_loss: 0.011663
# INFO:tensorflow:	+ Loss/classification_loss: 0.082725
# I0622 01:03:42.675584 140233411491712 model_lib_v2.py:1009] 	+ Loss/classification_loss: 0.082725
# INFO:tensorflow:	+ Loss/regularization_loss: 0.060237
# I0622 01:03:42.676858 140233411491712 model_lib_v2.py:1009] 	+ Loss/regularization_loss: 0.060237
# INFO:tensorflow:	+ Loss/total_loss: 0.154626
# I0622 01:03:42.677761 140233411491712 model_lib_v2.py:1009] 	+ Loss/total_loss: 0.154626
# Traceback (most recent call last):
#   File "model_main_tf2.py", line 115, in <module>
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "model_main_tf2.py", line 90, in main
#     wait_interval=300, timeout=FLAGS.eval_timeout)
#   File "/usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py", line 1128, in eval_continuously
#     checkpoint_dir, timeout=timeout, min_interval_secs=wait_interval):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 216, in checkpoints_iterator
#     time.sleep(time_to_next_eval)
# KeyboardInterrupt

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path ./models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config --trained_checkpoint_dir ./models/my_ssd_resnet50_fpn_cl_augmented/ --output_directory ./exported-models/my_ssd_resnet50_fpn_cl_augmented
# Out:
# 2021-07-10 05:15:24.189462: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-10 05:15:27.175092: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-10 05:15:27.188676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.189277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-10 05:15:27.189316: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-10 05:15:27.191840: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-10 05:15:27.191919: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-10 05:15:27.193536: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-07-10 05:15:27.193875: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-07-10 05:15:27.195753: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-07-10 05:15:27.196376: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-07-10 05:15:27.196569: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-10 05:15:27.196659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.197291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.197840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-10 05:15:27.198138: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-10 05:15:27.198343: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.198882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-07-10 05:15:27.198957: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.199526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.200051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-10 05:15:27.200104: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-10 05:15:27.655621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-10 05:15:27.655678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-10 05:15:27.655692: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-10 05:15:27.655854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.656513: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.657084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-10 05:15:27.657610: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-07-10 05:15:27.657658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15433 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0710 05:15:30.311645 139685806548864 deprecation.py:601] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0a70114610>, because it is not built.
# W0710 05:15:48.413966 139685806548864 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0a70114610>, because it is not built.
# 2021-07-10 05:15:57.618761: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0710 05:16:14.317742 139685806548864 save.py:243] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 520). These functions will not be directly callable after loading.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0710 05:16:18.638662 139685806548864 save.py:1240] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: ./exported-models/my_ssd_resnet50_fpn_cl_augmented/saved_model/assets
# I0710 05:16:19.975871 139685806548864 builder_impl.py:775] Assets written to: ./exported-models/my_ssd_resnet50_fpn_cl_augmented/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to ./exported-models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config
# I0710 05:16:20.686013 139685806548864 config_util.py:254] Writing pipeline config file to ./exported-models/my_ssd_resnet50_fpn_cl_augmented/pipeline.config

# %%
import tensorflow as tf
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL="/content/gdrive/My Drive/TensorFlow/workspace/training_demo/exported-models/my_ssd_resnet50_fpn_cl_augmented/saved_model"

print('Loading model...', end='')

# Load saved model and build the detection function
detect_fn=tf.saved_model.load(PATH_TO_SAVED_MODEL)

print('Done!')
# Out:
# Loading model...Done!

# %%
category_index=label_map_util.create_category_index_from_labelmap("/content/gdrive/My Drive/TensorFlow/workspace/training_demo/annotations/label_map.pbtxt",use_display_name=True)

# %%
img=['/content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/train/000058.jpg']
print(img)
# Out:
# ['/content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/train/000058.jpg']

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

for image_path in img:

    print('Running inference for {}... '.format(image_path), end='')
    image_np=load_image_into_numpy_array(image_path)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor=tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor=input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections=detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections=int(detections.pop('num_detections'))
    detections={key:value[0,:num_detections].numpy()
                   for key,value in detections.items()}
    detections['num_detections']=num_detections

    # detection_classes should be ints.
    detections['detection_classes']=detections['detection_classes'].astype(np.int64)
    image_np_with_detections=image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,     #max number of bounding boxes in the image
          min_score_thresh=.2,      #min prediction threshold
          agnostic_mode=False)
    # %matplotlib inline
    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
    plt.show()
# Out:
# Running inference for /content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/train/000058.jpg... Done

# %%
# %cd '/content/gdrive/My Drive/TensorFlow/workspace/training_demo'
# Out:
# /content/gdrive/My Drive/TensorFlow/workspace/training_demo

# %%
import EvaluationUtils as EvalUtils

base_dir = '/content/gdrive/My Drive/TensorFlow/workspace/training_demo/images/test/'
bbox_df, image_files_list, label_files_list = EvalUtils.retrieve_bounding_box_details(base_dir)

# %%
image_files_list_sort = sorted(image_files_list)
len(image_files_list_sort)
# Out:
# 109

# %% [markdown]
# ### INTEGRATED SCRIPT TO PERFORM DETECTION, COUNTING AND GENERATING CONFUSION MATRIX

# %%
import pandas as pd
import numpy as np
import cv2 as cv
def generate_matrices(min_score_thresh=.50, 
                      check_duplicate = False, 
                      check_partial_detection = False):
    eval_output_list = []
    for image_path in image_files_list_sort:
        image_name = image_path
        image_path = base_dir+ image_path
        cur_img = cv.imread(image_path)
        image_np=load_image_into_numpy_array(image_path)

        # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
        input_tensor=tf.convert_to_tensor(image_np)
        # The model expects a batch of images, so add an axis with `tf.newaxis`.
        input_tensor=input_tensor[tf.newaxis, ...]

        # input_tensor = np.expand_dims(image_np, 0)
        detections=detect_fn(input_tensor)

        # All outputs are batches tensors.
        # Convert to numpy arrays, and take index [0] to remove the batch dimension.
        # We're only interested in the first num_detections.
        num_detections=int(detections.pop('num_detections'))
        detections={key:value[0,:num_detections].numpy() for key,value in detections.items()}
        detections['num_detections']=num_detections

        # detection_classes should be ints.
        detections['detection_classes']=detections['detection_classes'].astype(np.int64)
        image_np_with_detections=image_np.copy()
        scores = [x for x in detections['detection_scores'] if x > min_score_thresh]
        detection_num = len(scores)
        det_boxs = detections['detection_boxes'][:detection_num]
        det_class = detections['detection_classes'][:detection_num]
        det_class_category = [category_index[x]['name'] for x in det_class]
        if (check_duplicate == True) and (det_boxs is not None) and (len(det_boxs)>0):
            det_boxs, det_class_category = EvalUtils.detect_duplicate_boxes(det_boxs, det_class_category)
            detection_num = len(det_class_category)
        if (check_partial_detection == True) and (det_boxs is not None) and (len(det_boxs)>0):
            det_boxs, det_class_category = EvalUtils.remove_partial_detections(cur_img, det_boxs, det_class_category)
            detection_num = len(det_class_category)
        bbox_file = bbox_df[bbox_df.filename == image_name]
        actual_aggregates = len(bbox_file[bbox_file['class'] == 'aggregate reticulocyte'])
        actual_punctate = len(bbox_file[bbox_file['class'] == 'punctate reticulocyte'])
        actual_erythrocyte = len(bbox_file[bbox_file['class'] == 'erythrocyte'])
        num_Actuals = len(bbox_file)

        bb_final_selection = bbox_file[['xmin', 'ymin', 'xmax', 'ymax', 'class']]
        bb_final_selection['match_found'] = 0
        list_bbox = bb_final_selection.values.tolist()
        Aggregate = 0
        Punctate = 0
        Erythrocyte = 0
        TP_Aggregate = 0
        TP_Punctate = 0
        TP_Erythrocyte = 0
        FP_Aggregate = 0
        FP_Punctate = 0
        FP_Erythrocyte = 0
        FN_Aggregate = 0
        FN_Punctate = 0
        FN_Erythrocyte = 0
        FP_Aggregate_TP_Punctate = 0
        FP_Aggregate_TP_Erythrocyte = 0
        FP_Punctate_TP_Aggregate = 0
        FP_Punctate_TP_Erythrocyte = 0
        FP_Erythrocyte_TP_Aggregate = 0
        FP_Erythrocyte_TP_Punctate = 0
        NoMatch = 0
        for box_category in zip(det_boxs, det_class_category):
            box, category = box_category[0], box_category[1]
            #matching_box = list_bbox[0]
            IoU = 0
            bbox_index = 0
            for ind, actuals in enumerate(list_bbox):
                # Only check intersection with those boxes which are not yet matched
                # actuals[5] correspond to match_found column
                if actuals[5] == 0:
                    curIoU = EvalUtils.compute_IOU_score(actuals[:4], box)
                    if(curIoU > IoU):
                        bbox_index = ind
                        IoU = curIoU
            if category == 'aggregate reticulocyte':
                Aggregate = Aggregate+1
            elif category == 'punctate reticulocyte':
                Punctate = Punctate+1
            elif category == 'erythrocyte':
                Erythrocyte = Erythrocyte+1  
            # If the dtectected category ->category
            # Actual category <-list_bbox[bbox_index][4]
            # If both are same its a True Positive Detection, Good
            if (IoU > 0):
                #Setting indication that this box is already found a match with label having higher score
                list_bbox[bbox_index][5] = 1
                actual_category = list_bbox[bbox_index][4]
                if actual_category == category:
                    if category == 'aggregate reticulocyte':
                        TP_Aggregate = TP_Aggregate+1
                    elif category == 'punctate reticulocyte':
                        TP_Punctate = TP_Punctate+1
                    elif category == 'erythrocyte':
                        TP_Erythrocyte = TP_Erythrocyte+1  
                else:
                    # Else is for FP detections           
                    if category == 'aggregate reticulocyte' and actual_category == 'punctate reticulocyte':
                        FP_Aggregate_TP_Punctate = FP_Aggregate_TP_Punctate + 1
                    if category == 'aggregate reticulocyte' and actual_category == 'erythrocyte':
                        FP_Aggregate_TP_Erythrocyte = FP_Aggregate_TP_Erythrocyte + 1
                    if category == 'punctate reticulocyte' and actual_category == 'aggregate reticulocyte':
                        FP_Punctate_TP_Aggregate = FP_Punctate_TP_Aggregate + 1
                    if category == 'punctate reticulocyte' and actual_category == 'erythrocyte':
                        FP_Punctate_TP_Erythrocyte = FP_Punctate_TP_Erythrocyte + 1
                    elif category == 'erythrocyte' and actual_category == 'aggregate reticulocyte':
                        FP_Erythrocyte_TP_Aggregate = FP_Erythrocyte_TP_Aggregate + 1
                    elif category == 'erythrocyte' and actual_category == 'punctate reticulocyte':
                        FP_Erythrocyte_TP_Punctate = FP_Erythrocyte_TP_Punctate + 1  
            else:
                # These are extra detections - False Positives
                if category == 'aggregate reticulocyte':
                    FP_Aggregate = FP_Aggregate+1
                elif category == 'punctate reticulocyte':
                    FP_Punctate = FP_Punctate+1
                elif category == 'erythrocyte':
                    FP_Erythrocyte = FP_Erythrocyte+1
        #if num_Actuals >  detection_num:
        for i in range(len(list_bbox)):
            if list_bbox[i][5] == 0:
                if list_bbox[i][4] == 'aggregate reticulocyte':
                    FN_Aggregate = FN_Aggregate+1
                elif list_bbox[i][4] == 'punctate reticulocyte':
                    FN_Punctate = FN_Punctate+1
                elif list_bbox[i][4] == 'erythrocyte':
                    FN_Erythrocyte = FN_Erythrocyte+1                 

        imagewise_data = [image_name, TP_Aggregate, TP_Punctate, TP_Erythrocyte, 
                        FP_Aggregate, FP_Punctate, FP_Erythrocyte, 
                        FP_Aggregate_TP_Punctate, FP_Aggregate_TP_Erythrocyte,
                        FP_Punctate_TP_Aggregate, FP_Punctate_TP_Erythrocyte,
                        FP_Erythrocyte_TP_Aggregate, FP_Erythrocyte_TP_Punctate,
                        FN_Aggregate, FN_Punctate, FN_Erythrocyte,
                        Aggregate, Punctate, Erythrocyte, 
                        actual_aggregates, actual_punctate, actual_erythrocyte, 
                        num_Actuals, detection_num]
        column_names = ['image_name', 'TP_Aggregate', 'TP_Punctate', 'TP_Erythrocyte', 
                      'FP_Aggregate', 'FP_Punctate', 'FP_Erythrocyte',
                      'FP_Aggregate_TP_Punctate', 'FP_Aggregate_TP_Erythrocyte',
                      'FP_Punctate_TP_Aggregate', 'FP_Punctate_TP_Erythrocyte',
                      'FP_Erythrocyte_TP_Aggregate', 'FP_Erythrocyte_TP_Punctate',
                      'FN_Aggregate', 'FN_Punctate', 'FN_Erythrocyte', 
                      'Aggregate', 'Punctate', 'Erythrocyte', 
                      'Actual_aggregates', 'Actual_punctates','Actual_erythrocytes','Actual', 'Detected']
        eval_output_list.append(imagewise_data)
        
    prediction_data = pd.DataFrame(data =eval_output_list, columns = column_names)
    return prediction_data

# %%
AccuracyList = []
for score in np.arange(0.4, 0.8, 0.05):
    prediction_data = generate_matrices(score, True, True)
    confusion_matrix, confusion_df = EvalUtils.create_confusion_matrix(prediction_data)
    Accuracy, Accuracy_aggregate, Accuracy_punctate, Accuracy_erythrocyte = EvalUtils.compute_accuracy(confusion_matrix)
    AccuracyList.append([score, Accuracy, Accuracy_aggregate, Accuracy_punctate, Accuracy_erythrocyte])

AccDF= pd.DataFrame(AccuracyList,
                    columns = ['Score', 'Total', 'Aggregate', 'Punctate', 'Erythrocyte'])
AccDF
# Out:
#    Score     Total  Aggregate  Punctate  Erythrocyte
# 0   0.40  0.883951   0.961165  0.800000     0.880184
# 1   0.45  0.888060   0.961165  0.807229     0.884259
# 2   0.50  0.877805   0.970588  0.767442     0.877934
# 3   0.55  0.857855   0.970588  0.732558     0.854460
# 4   0.60  0.830424   0.970588  0.655172     0.834906
# 5   0.65  0.810474   0.980000  0.647727     0.798122
# 6   0.70  0.763819   0.960000  0.576471     0.746479
# 7   0.75  0.721106   0.940594  0.517647     0.698113

# %%
prediction_data = generate_matrices(0.45, True, True)
confusion_matrix, confusion_df = EvalUtils.create_confusion_matrix(prediction_data)
Accuracy, Accuracy_aggregate, Accuracy_punctate, Accuracy_erythrocyte = EvalUtils.compute_accuracy(confusion_matrix)
confusion_df
# Out:
#    Aggregate  Punctate  Erythrocyte  FP  FN
# 0         99         4            0   0   0
# 1          1        67           14   0   1
# 2          0        16          191   6   3

# %%
print("Aggregate Reticulocyte Count:", sum(confusion_matrix[0]))
print("Punctate Reticulocyte Count:", sum(confusion_matrix[1]))
print("Erythrocyte Count:", sum(confusion_matrix[2]))
# Out:
# Aggregate Reticulocyte Count: 103
# Punctate Reticulocyte Count: 83
# Erythrocyte Count: 216

# %% [markdown]
# ### EVALUATION WITHOUT POST PROCESSING STEPS

# %%
prediction_data = generate_matrices(0.45, False, False)
confusion_matrix, confusion_df = EvalUtils.create_confusion_matrix(prediction_data)
Accuracy, Accuracy_aggregate, Accuracy_punctate, Accuracy_erythrocyte = EvalUtils.compute_accuracy(confusion_matrix)
confusion_df
# Out:
#    Aggregate  Punctate  Erythrocyte  FP  FN
# 0         99         4            0   1   0
# 1          1        67           14   6   1
# 2          0        16          192  15   2

# %%
Accuracy, Accuracy_aggregate, Accuracy_punctate, Accuracy_erythrocyte
# Out:
# (0.8564593301435407,
#  0.9519230769230769,
#  0.7528089887640449,
#  0.8533333333333334)
